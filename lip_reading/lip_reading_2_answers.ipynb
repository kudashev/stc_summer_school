# %% [markdown]
# В данном занятии мы построим многослойную нейронную сеть (Deep Neural Network, DNN) при помощи TensorFlow, которая будет осущесвлять классификацию каждого входного фрейма (с некоторым контекстом) по фонемам (в том числе паузе).

# %%
import os

# Необходимо явно указать те CUDA-совместимые устройства, которые будут использоваться,
# чтобы ограничить доступ TensorFlow на остальные
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
import numpy as np

import fnmatch

import matplotlib.pyplot as plt 
import random

# %matplotlib inline

# %% [markdown]
# В качестве входных данных для нейронной сети будем использовать в произвольной комбинации следующие признаки (<code>features_types</code>):
# - mfcc
# - pca_W (проекция $PCA_W$ из предыдущей работы изображений губ 50x30 из предыдущей работы)
# - landmarks (пара расстояний между верхней и нижней губой и между уголками рта)
# - hog_pca_W (проекция $PCA_W$ HOG-признаков)
#
# Входным вектором на $i$-м кадре для DNN будет текущий $i$-й вектор + дополнительный контекст, который задается двумя параметрами: <code>[context_size, context_shift]</code> для каждого типа признаков отдельно. context_size - размер контекста (количество фреймов слева и справа, которые добавляем), context_shift - шаг между добавляемыми векторами. К примеру, контекст [3, 2] означает, что мы для i-го кадра будем формировать вектор размером (1 + 2\*3)\*dim путем конкатенации следующих кадров: (i-6), (i-4), (i-2), i, (i+2), (i+4), (i+6)

# %%
work_dir = "../../data/lip_reading/"
features_dir = "2_features/"

#признаки для обучения DNN (можно указывать любую комбинацию)
features_types = ["pca_W", "mfcc"]

#контекст [context_size, context_shift]
features_context = [ [2, 4], [3, 2] ]
assert(len(features_context) == len(features_types)), "Length of features_types and features_context must be equal"

output_dir = "_".join(features_types) + "/"
dnn_path = "./models/dnn/" + output_dir
predictions_path = "./3_predictions/" + output_dir

#рассчитаем размер входного вектора DNN
x_dim = 0
for i in range(len(features_types)):
    files = fnmatch.filter(os.listdir(work_dir + features_dir + features_types[i] + "/test/"), "*.npy")
    features = np.load(work_dir + features_dir + features_types[i] + "/test/" + files[0])
    context_size, context_shift = features_context[i]
    x_dim +=(context_size * 2 + 1)*features.shape[1]

    
phones = [l.strip() for l in open(work_dir + features_dir + "phones").readlines()]
phones_indx_mapping = {p:i for i,p in enumerate(phones)}
phones_num = len(phones_indx_mapping)

# %% [markdown]
# Функция подготовки признаков:
# - загрузка файла(ов) признаков
# - нормировка
# - добавление контекста
# - объединение в один массив
# - добавление меток классов
#
# Входные данные:
# <code>file</code> - имя файла;
# <code>features_dirs</code> - список путей к признакам;
# <code>context</code> - контекст;
# <code>phones_num</code> - количество фонем в разметке;
# <code>align</code> - выравнивание по фонемам (хранит метки фонем для каждого фрейма), метка 0 используется для фонемы "пауза"
#
# Необходимо, чтобы все признаки были предварительно построены с одинаковым frame-rate (в данной работе - 100 кадров в сек.) для обеспечения синхронности

# %%
def prepare_train_data(file, features_dirs, features_context, phones_num, align = np.array([])):
    
    max_pause_frames = 30
    assert (len(features_dirs) == len(features_context))
    
    # Загрузка признаков
    features_list = []
    for d in features_dirs:
        features = np.load(d + file)
        # mean normalization
        features = (features - features.mean(axis=0))
        features_list.append(features)
    
    frames_num = features_list[0].shape[0]
    for features in features_list:
        frames_num = min(frames_num, features.shape[0])  
    speech_start = 0
    speech_end = frames_num
    if len(align):
        frames_num = min(frames_num, align.shape[0])
        speech_start = np.nonzero(align)[0].min()
        speech_end = np.nonzero(align)[0].max() + 1
    
    frames_start = max(0, speech_start - max_pause_frames)
    frames_end = min(frames_num, speech_end + max_pause_frames)
    assert (frames_end > frames_start), "Prepare data error: (frames_end <= frames_start)"
    
    # расчет финального размера признаков
    result_x_dim = 0
    for i,features in enumerate(features_list):
        context_size, context_shift = features_context[i]
        dim = features.shape[1]
        result_x_dim += dim*(context_size*2 + 1)
        
    x_y = np.zeros([frames_end - frames_start, result_x_dim + phones_num])
    
    dim_shift = 0
    for i,features in enumerate(features_list):
        context_size, context_shift = features_context[i]
        dim = features.shape[1]
        for context in range(-context_size, context_size+1):
            x_y[:, dim_shift + dim*(context_size + context): dim_shift + dim*(context_size + context + 1)] = np.roll(features, context*context_shift, axis=0)[frames_start:frames_end,:]
        dim_shift += dim*(context_size*2 + 1)
    
    # добавление меток классов
    if len(align):
        for ph in range(phones_num):
            x_y[np.where(align[frames_start:frames_end] == ph)[0], result_x_dim + ph] = 1
    
    return x_y

# %% [markdown]
# Вспомогательная функция - загрузка всех данных для списка пользователей <code>persons</code>

# %%
def prepare_data_for_persons(persons, features_dirs, features_context, phones_num, align_train = {}):
    assert (len(features_dirs) > 0), "Error: len(features_dirs) > 0"
    assert (len(features_dirs) == len(features_context)), "Error: len(features_dirs) == len(features_context)"
    
    files_list_0 = fnmatch.filter(os.listdir(features_dirs[0]), "*.npy")
    
    files_list = []
    for f in files_list_0:
        person_id = f.split('_')[0]
        if (person_id in persons):
            is_ok = True
            for d in features_dirs:
                if (not os.path.isfile(d + f)):
                    is_ok = False
                    break;
            if is_ok:
                files_list.append(f)
    
    print("Files num: {}".format(len(files_list)))

    data_x_y_list = []
    for i,file in enumerate(files_list):
        if (i%1000 == 0):
            print("Processed {} / {}".format(i, len(files_list)))
        filename = os.path.splitext(file)[0]
        align = align_train.get(filename, np.array([]))
        if len(align):
            x_y = prepare_train_data(file, features_dirs, features_context, phones_num, align)
            data_x_y_list.append(x_y)
    data_x_y = np.concatenate(data_x_y_list)
    return data_x_y

# %% [markdown]
# Для обучения DNN будем использовать TensorFlow. Для начала будет использована простейшая архитектура: входной слой + несколько внутренних полносвязных слоев + выходной softmax слой.
#
# <b> Задание 1.</b> Сформировать нейронную сеть со следующими параметрами:
# - количество внутренних слоев - 4
# - количество нейронов в каждом внутреннем слое - 256
# - активационная функция для внутренних слоев - <code>tf.nn.sigmoid</code>
# - первоначальная инициализация весов - при помощи <code>tf.random_normal</code>

# %%
n_nodes_hl1 = 256
n_nodes_hl2 = 256
n_nodes_hl3 = 256
n_nodes_hl4 = 256

n_classes = phones_num
x = tf.placeholder(tf.float32, [None, x_dim])

# пригодится в дальнейшем (не использовать в этом блоке)
y = tf.placeholder(tf.float32, [None, n_classes])

#--------------------------- TODO -----------------------------------------
# building graph:
hidden_layer_1 = {'weight': tf.Variable(tf.random_normal([x_dim, n_nodes_hl1], mean=0.0, stddev=0.05), name='w1'),
                  'biases': tf.Variable(tf.zeros([n_nodes_hl1]), name='b1')}

hidden_layer_2 = {'weight': tf.Variable(tf.random_normal([n_nodes_hl1, n_nodes_hl2], mean=0.0, stddev=0.05), name='w2'),
                  'biases': tf.Variable(tf.zeros([n_nodes_hl2]), name='b2')}

hidden_layer_3 = {'weight': tf.Variable(tf.random_normal([n_nodes_hl2, n_nodes_hl3], mean=0.0, stddev=0.05), name='w3'),
                  'biases': tf.Variable(tf.zeros([n_nodes_hl3]), name='b3')}

hidden_layer_4 = {'weight': tf.Variable(tf.random_normal([n_nodes_hl3, n_nodes_hl4], mean=0.0, stddev=0.05), name='w4'),
                  'biases': tf.Variable(tf.zeros([n_nodes_hl4]), name='b4')}

output_layer = {'weight': tf.Variable(tf.random_normal([n_nodes_hl3, n_classes], mean=0.0, stddev=0.05), name='w5'),
                'biases': tf.Variable(tf.zeros([n_classes]), name='b5')}

l1 = tf.add(tf.matmul(x, hidden_layer_1['weight']), hidden_layer_1['biases'])
l1 = tf.nn.sigmoid(l1)

l2 = tf.add(tf.matmul(l1, hidden_layer_2['weight']), hidden_layer_2['biases'])
l2 = tf.nn.sigmoid(l2)

l3 = tf.add(tf.matmul(l2, hidden_layer_3['weight']), hidden_layer_3['biases'])
l3 = tf.nn.sigmoid(l3)

l4 = tf.add(tf.matmul(l3, hidden_layer_4['weight']), hidden_layer_4['biases'])
l4 = tf.nn.sigmoid(l4)

# output - это результат вычисления непосредственно перед softmax
output = tf.add(tf.matmul(l4, output_layer['weight']), output_layer['biases'])
#--------------------------------------------------------------------------

output_softmax = tf.nn.softmax(output) # необходимо в дальнейшем при получении predict

# функция стоимости
cost_fun = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=output,
                                                                  labels=y))
# при обучении будем использовать оптимизатор Adam
train_step = tf.train.AdamOptimizer().minimize(cost_fun)

# подсчет точности предсказания
cor_predict = tf.equal(tf.arg_max(y, 1), tf.arg_max(output, 1))
accuracy = tf.reduce_mean(tf.cast(cor_predict, tf.float32))

# %% [markdown]
# Подготовка данных для обучения DNN
#
# <b>Внимание!</b> В данном примере осуществляется загрузка всех признаков в оперативную память. Если памяти не хватает, необходимо переделать процедуру обучения DNN таким образом, чтобы batch формировался динамически. Возможный вариант реализации:
# - п.0 перед началов обучения формируется список файлов обучения
# - п.1 перед каждой эпохой список файлов перемешивается
# - п.2 в память загружается ограниченное количество файлов (к примеру, 100 штук) и batch-и берутся из них
# - п.3 если данные закончились, загружаем очередные 100 файлов и переходим к п.2

# %%
print("Load alignment")
align_train = {}

for line in open(work_dir + features_dir + "new_alig").readlines():
    line_split = line.strip().split(' ')
    align_train[line_split[0]] = np.array([phones_indx_mapping[phone] for phone in line_split[1:]])

features_train_dirs = []
for features_type in features_types:
    features_train_dirs.append(work_dir + features_dir + features_type + "/train/")

#files_train = fnmatch.filter(os.listdir(features_train_dir), "*.npy")
#print("Train files num: {}".format(len(files_train)))

print("Load features from: " + str(features_train_dirs))
persons_train = [l.strip() for l in open(work_dir + features_dir + "train_persons.list").readlines()]
persons_validate = [l.strip() for l in open(work_dir + features_dir + "validate_persons.list").readlines()]
data_x_y_train = prepare_data_for_persons(persons_train, features_train_dirs,  features_context, phones_num, align_train)
data_x_y_validate = prepare_data_for_persons(persons_validate, features_train_dirs,  features_context, phones_num, align_train)
# Out:
# Load alignment
# Load features from: ['../../data/lip_reading/2_features/pca_W/train/', '../../data/lip_reading/2_features/mfcc/train/']
# Files num: 8113
# Processed 0 / 8113
# Processed 1000 / 8113
# Processed 2000 / 8113
# Processed 3000 / 8113
# Processed 4000 / 8113
# Processed 5000 / 8113
# Processed 6000 / 8113
# Processed 7000 / 8113
# Processed 8000 / 8113
# Files num: 1322
# Processed 0 / 1322
# Processed 1000 / 1322

# %% [markdown]
# Обучение DNN

# %%
os.system("mkdir -p  " + dnn_path)
with open(dnn_path + "features_context.txt", "w") as f:
    f.write(str(features_context))
    
with open(dnn_path + "features_types.txt", "w") as f:
    f.write(str(features_types))

file_log = open(dnn_path + "log.txt", "w")

saver = tf.train.Saver()

batch_size = 256
# run session:
batches_num = int(data_x_y_train.shape[0] / batch_size)

config=tf.ConfigProto()
config.gpu_options.allow_growth = True # запрещаем занимать всю доступную память на GPU

with tf.Session(config=config) as sess:
    tf.global_variables_initializer().run()
    print('TRAINING IS STARTED...')
    for epoch in range(10):
        epoch_loss = 0
        # перед каждой эпохой перемешиваем данные
        np.random.shuffle(data_x_y_train)
        for batch in range(batches_num):
            batch_xs = data_x_y_train[batch*batch_size:(batch+1)*batch_size, 0:x_dim]
            batch_ys = data_x_y_train[batch*batch_size:(batch+1)*batch_size, x_dim:]
            _, c = sess.run([train_step, cost_fun], {x: batch_xs, y: batch_ys})
            epoch_loss += c
        print('Epoch: {}, loss: {}'.format(epoch, epoch_loss))
        file_log.write('Epoch: {}, loss: {}\n'.format(epoch, epoch_loss))
        
        data_validate_x = data_x_y_validate[:, 0:x_dim]
        data_validate_y = data_x_y_validate[:, x_dim:]
        frames_test_speech = np.where(data_validate_y[:,0] == 0)[0]
        
        # считаем accuracy на валидационном множестве
        accuracy_full = sess.run(accuracy, {x: data_validate_x, y: data_validate_y})
        # accuracy по всем фонемам, кроме фонемы "пауза"
        accuracy_speech_only = sess.run(accuracy, {x: data_validate_x[frames_test_speech,:], y: data_validate_y[frames_test_speech,:]})
        print('Accuracy: {}, accuracy (speech only): {}'.format(accuracy_full, accuracy_speech_only))
        file_log.write('Accuracy: {}, accuracy (speech only): {}\n'.format(accuracy_full, accuracy_speech_only))
        saver.save(sess, dnn_path + "epoch_{}".format(epoch))
file_log.close()
# Out:
# TRAINING IS STARTED...
# Epoch: 0, loss: 11730.236666321754
# Accuracy: 0.7223834991455078, accuracy (speech only): 0.6965517401695251
# Epoch: 1, loss: 8995.637139260769
# Accuracy: 0.7413422465324402, accuracy (speech only): 0.7187196016311646
# Epoch: 2, loss: 8327.828028827906
# Accuracy: 0.750708281993866, accuracy (speech only): 0.7277534604072571
# Epoch: 3, loss: 7974.503780275583
# Accuracy: 0.7567722201347351, accuracy (speech only): 0.7373457551002502
# Epoch: 4, loss: 7731.341266602278
# Accuracy: 0.7590792775154114, accuracy (speech only): 0.74509197473526
# Epoch: 5, loss: 7557.149601370096
# Accuracy: 0.7593922019004822, accuracy (speech only): 0.7395803332328796
# Epoch: 6, loss: 7423.085683584213
# Accuracy: 0.7615479230880737, accuracy (speech only): 0.7458705902099609
# Epoch: 7, loss: 7309.96988388896
# Accuracy: 0.7631679177284241, accuracy (speech only): 0.7493460178375244
# Epoch: 8, loss: 7214.288057923317
# Accuracy: 0.7647907733917236, accuracy (speech only): 0.7478048801422119
# Epoch: 9, loss: 7134.341457188129
# Accuracy: 0.7628555297851562, accuracy (speech only): 0.7422162890434265

# %% [markdown]
# Подсчет постериоров тестовой базы

# %%
features_test_dirs = []
for features_type in features_types:
    features_test_dirs.append(work_dir + features_dir + features_type + "/test/")

test_files = fnmatch.filter(os.listdir(features_test_dirs[0]), "*.npy")
    
os.system("mkdir -p " + predictions_path)

config=tf.ConfigProto()
config.gpu_options.allow_growth = True

saver = tf.train.Saver()

with tf.Session(config=config) as sess:
    print ("Restoring session: " + tf.train.latest_checkpoint(dnn_path))
    saver.restore(sess, tf.train.latest_checkpoint(dnn_path))
    
    for file in test_files:
        
        x_y_test = prepare_train_data(file, features_test_dirs, features_context, phones_num)
    
        predict = sess.run(output_softmax, {x: x_y_test[:,0:x_dim]})
        np.save(predictions_path + file, predict.astype(np.float32))
        print("processed: " + file + "(frames num: {})".format(predict.shape[0]))
# Out:
# Restoring session: ./models/dnn/pca_W_mfcc/epoch_9
# INFO:tensorflow:Restoring parameters from ./models/dnn/pca_W_mfcc/epoch_9
# processed: M0071_01_28304_iPhone_6s.npy(frames num: 252)
# processed: F0020_01_87901_iPhone_6s.npy(frames num: 376)
# processed: F0031_01_98264_iPhone_Iphone5.npy(frames num: 461)
# processed: M0041_02_1340768592_Android_SM.npy(frames num: 626)
# processed: M0012_03_84312_Android_SM_Gal_J3.npy(frames num: 215)
# processed: M0041_01_39605_Android_htc.npy(frames num: 442)
# processed: M0004_02_1894372056_iPhone_iphone6.npy(frames num: 660)
# processed: M0089_01_34789_iPhone_6s.npy(frames num: 512)
# processed: F0052_03_32198_iPhone_6s.npy(frames num: 210)
# processed: M0060_01_8102574936_iPhone_6s.npy(frames num: 489)
# processed: M0054_03_54329_Android_nexus.npy(frames num: 339)
# processed: M0067_02_49586_Android_nexus.npy(frames num: 432)
# processed: M0046_03_6574019823_Android_SM.npy(frames num: 640)
# processed: M0070_02_37528_Android_SM_Gal_J3.npy(frames num: 369)
# processed: F0095_02_26389_Android_nexus.npy(frames num: 269)
# processed: F0050_01_2964851730_Android_SM.npy(frames num: 558)
# processed: F0022_03_12948_iPhone_6s.npy(frames num: 328)
# processed: F0199_01_3621475890_Android_nexus.npy(frames num: 391)
# processed: F0050_02_0578342619_Android_htc.npy(frames num: 650)
# processed: F0191_02_94863_Android_nexus.npy(frames num: 281)
# processed: M0004_02_89254_Android_htc.npy(frames num: 397)
# processed: F0172_01_72901_Android_SM.npy(frames num: 255)
# processed: F0169_03_0319268457_Android_nexus.npy(frames num: 713)
# processed: M0075_03_1025739486_Android_SM.npy(frames num: 833)
# processed: F0052_02_43178_Android_htc.npy(frames num: 295)
# processed: M0036_02_5064821793_Android_htc.npy(frames num: 579)
# processed: F0042_02_29640_Android_htc.npy(frames num: 234)
# processed: M0007_01_54398_iPhone_6s.npy(frames num: 399)
# processed: M0055_02_4029763518_iPhone_iphone6.npy(frames num: 855)
# processed: F0034_03_42950_Android_nexus.npy(frames num: 400)
# processed: M0078_02_4258637190_Android_SM_Gal_J3.npy(frames num: 463)
# processed: M0044_02_4029763518_iPhone_iphone6.npy(frames num: 689)
# processed: M0088_02_85109_Android_nexus.npy(frames num: 336)
# processed: M0053_03_32054_iPhone_6s.npy(frames num: 239)
# processed: F0022_01_5326071948_iPhone_6s.npy(frames num: 575)
# processed: F0090_02_8054723916_Android_nexus.npy(frames num: 752)
# processed: F0073_03_48790_Android_htc.npy(frames num: 238)
# processed: M0049_01_5031862974_iPhone_Iphone5.npy(frames num: 554)
# processed: M0004_01_54398_iPhone_6s.npy(frames num: 459)
# processed: M0039_01_43876_iPhone_Iphone5.npy(frames num: 385)
# processed: M0070_03_62045_iPhone_iphone6.npy(frames num: 295)
# processed: M0089_01_45213_Android_SM.npy(frames num: 464)
# processed: F0152_03_3978520416_iPhone_6s.npy(frames num: 401)
# processed: M0059_02_04279_iPhone_iphone6.npy(frames num: 462)
# processed: F0154_01_8021397465_Android_SM.npy(frames num: 700)
# processed: M0056_02_29640_Android_htc.npy(frames num: 303)
# processed: F0200_02_71024_Android_SM.npy(frames num: 303)
# processed: F0152_03_95102_iPhone_6s.npy(frames num: 199)
# processed: F0119_02_0548132976_Android_SM_Gal_J3.npy(frames num: 525)
# processed: M0062_01_41853_iPhone_6s.npy(frames num: 339)
# processed: M0077_01_47016_iPhone_6s.npy(frames num: 427)
# processed: F0197_01_31049_Android_nexus.npy(frames num: 477)
# processed: M0001_03_4697803125_Android_SM_Gal_J3.npy(frames num: 1236)
# processed: F0154_02_51386_iPhone_iphone6.npy(frames num: 373)
# processed: M0048_02_4910725836_Android_htc.npy(frames num: 506)
# processed: F0050_02_03924_Android_htc.npy(frames num: 404)
# processed: M0006_03_59012_Android_SM_Gal_J3.npy(frames num: 196)
# processed: M0082_02_8643201957_Android_nexus.npy(frames num: 462)
# processed: F0173_01_85346_Android_SM.npy(frames num: 204)
# processed: F0130_01_90572_Android_SM.npy(frames num: 226)
# processed: F0095_03_2738015469_iPhone_iphone6.npy(frames num: 723)
# processed: F0197_01_1052698347_Android_nexus.npy(frames num: 932)
# processed: F0154_01_3407869152_iPhone_6s.npy(frames num: 647)
# processed: F0027_01_23679_iPhone_6s.npy(frames num: 323)
# processed: M0071_03_4532091867_iPhone_iphone6.npy(frames num: 512)
# processed: M0076_03_79428_iPhone_iphone6.npy(frames num: 224)
# processed: F0020_03_0931472685_Android_SM.npy(frames num: 528)
# processed: F0005_03_4697803125_Android_SM_Gal_J3.npy(frames num: 454)
# processed: F0191_02_04837_Android_SM_Gal_J3.npy(frames num: 275)
# processed: M0082_02_03271_Android_nexus.npy(frames num: 229)
# processed: M0004_02_0578342619_Android_htc.npy(frames num: 658)
# processed: F0200_03_7264359180_Android_htc.npy(frames num: 625)
# processed: M0055_02_4910725836_Android_htc.npy(frames num: 861)
# processed: M0046_03_0931472685_Android_SM.npy(frames num: 667)
# processed: F0157_03_53061_iPhone_iphone6.npy(frames num: 371)
# processed: F0010_02_2174905683_Android_htc.npy(frames num: 541)
# processed: M0026_01_48150_iPhone_6s.npy(frames num: 301)
# processed: M0071_02_4602935718_Android_nexus.npy(frames num: 497)
# processed: F0005_01_63470_iPhone_6s.npy(frames num: 389)
# processed: M0083_03_48790_Android_htc.npy(frames num: 150)
# processed: M0074_02_98542_iPhone_6s.npy(frames num: 260)
# processed: M0056_01_87901_iPhone_6s.npy(frames num: 246)
# processed: M0065_02_0571928643_Android_nexus.npy(frames num: 603)
# processed: F0034_03_9263475180_Android_nexus.npy(frames num: 800)
# processed: F0169_01_72901_Android_SM.npy(frames num: 430)
# processed: M0079_03_48721_Android_SM.npy(frames num: 277)
# processed: F0021_03_5267981034_iPhone_6s.npy(frames num: 459)
# processed: M0089_01_65718_iPhone_6s.npy(frames num: 514)
# processed: M0077_02_49826_Android_nexus.npy(frames num: 412)
# processed: M0001_01_1324670895_iPhone_6s.npy(frames num: 1021)
# processed: F0200_01_65394_Android_SM_Gal_J3.npy(frames num: 368)
# processed: F0201_02_04279_iPhone_iphone6.npy(frames num: 309)
# processed: F0169_03_24706_Android_nexus.npy(frames num: 483)
# processed: M0001_02_27459_Android_SM.npy(frames num: 643)
# processed: M0089_03_4532091867_iPhone_iphone6.npy(frames num: 801)
# processed: F0011_02_04279_iPhone_iphone6.npy(frames num: 411)
# processed: M0030_01_70296_iPhone_Iphone5.npy(frames num: 237)
# processed: M0041_03_18924_Android_SM.npy(frames num: 238)
# processed: F0009_02_51386_iPhone_iphone6.npy(frames num: 339)
# processed: F0154_03_34690_Android_nexus.npy(frames num: 381)
# processed: M0054_03_15843_Android_nexus.npy(frames num: 315)
# processed: F0052_01_23679_iPhone_6s.npy(frames num: 424)
# processed: F0022_02_1230895746_iPhone_Iphone5.npy(frames num: 446)
# processed: M0082_03_97642_Android_htc.npy(frames num: 368)
# processed: M0044_02_1392408567_iPhone_iphone6.npy(frames num: 762)
# processed: F0191_03_83971_iPhone_iphone6.npy(frames num: 295)
# processed: F0199_01_7239856140_Android_SM_Gal_J3.npy(frames num: 461)
# processed: F0152_01_15847_Android_SM.npy(frames num: 282)
# processed: M0038_02_5213840967_Android_htc.npy(frames num: 930)
# processed: M0013_03_4306759182_Android_SM_Gal_J3.npy(frames num: 785)
# processed: M0045_01_72613_iPhone_Iphone5.npy(frames num: 423)
# processed: M0053_03_97513_Android_SM.npy(frames num: 294)
# processed: F0169_03_1923478650_Android_SM_Gal_J3.npy(frames num: 823)
# processed: F0069_03_6382975401_Android_htc.npy(frames num: 447)
# processed: F0197_01_28701_Android_SM_Gal_J3.npy(frames num: 442)
# processed: M0046_01_69175_Android_htc.npy(frames num: 440)
# processed: F0095_03_62045_iPhone_iphone6.npy(frames num: 338)
# processed: F0130_02_91082_Android_nexus.npy(frames num: 186)
# processed: M0077_01_23985_iPhone_6s.npy(frames num: 396)
# processed: M0026_03_38467_iPhone_6s.npy(frames num: 349)
# processed: F0172_01_0768123549_iPhone_6s.npy(frames num: 424)
# processed: F0200_03_6382074195_iPhone_iphone6.npy(frames num: 537)
# processed: M0079_01_1427859063_iPhone_6s.npy(frames num: 462)
# processed: M0046_01_9307426185_iPhone_Iphone5.npy(frames num: 649)
# processed: F0021_03_46972_Android_SM.npy(frames num: 284)
# processed: F0051_03_1576042983_Android_nexus.npy(frames num: 506)
# processed: M0038_03_85792_iPhone_6s.npy(frames num: 351)
# processed: M0039_03_16074_Android_SM_Gal_J3.npy(frames num: 309)
# processed: F0022_02_1763092458_iPhone_Iphone5.npy(frames num: 484)
# processed: F0035_02_04279_iPhone_iphone6.npy(frames num: 336)
# processed: M0013_01_9761823504_iPhone_6s.npy(frames num: 772)
# processed: M0047_03_73068_Android_SM_Gal_J3.npy(frames num: 291)
# processed: F0052_03_2594680137_iPhone_6s.npy(frames num: 350)
# processed: F0117_02_0582397146_Android_htc.npy(frames num: 577)
# processed: M0030_03_6574019823_Android_SM.npy(frames num: 602)
# processed: M0038_01_4762598103_Android_htc.npy(frames num: 695)
# processed: M0047_01_5031862974_iPhone_Iphone5.npy(frames num: 541)
# processed: M0045_03_09687_Android_SM.npy(frames num: 599)
# processed: M0059_03_18970_Android_SM_Gal_J3.npy(frames num: 384)
# processed: M0012_02_2174905683_Android_htc.npy(frames num: 385)
# processed: F0051_03_3792846105_Android_nexus.npy(frames num: 602)
# processed: M0071_03_38964_Android_htc.npy(frames num: 301)
# processed: F0168_03_6382074195_iPhone_iphone6.npy(frames num: 398)
# processed: M0057_03_02864_iPhone_6s.npy(frames num: 374)
# processed: M0076_01_28304_iPhone_6s.npy(frames num: 248)
# processed: M0041_02_97085_Android_SM.npy(frames num: 300)
# processed: F0009_01_4351796082_iPhone_6s.npy(frames num: 546)
# processed: F0042_02_1392408567_iPhone_iphone6.npy(frames num: 487)
# processed: F0029_02_42365_iPhone_iphone6.npy(frames num: 303)
# processed: F0169_02_8036592741_Android_htc.npy(frames num: 872)
# processed: F0021_03_0931472685_Android_SM.npy(frames num: 464)
# processed: M0043_02_95230_Android_htc.npy(frames num: 247)
# processed: M0081_02_74096_Android_SM_Gal_J3.npy(frames num: 284)
# processed: F0050_01_67542_Android_SM.npy(frames num: 408)
# processed: F0052_01_2637015489_iPhone_6s.npy(frames num: 841)
# processed: F0051_03_86071_Android_nexus.npy(frames num: 315)
# processed: F0015_02_46783_Android_htc.npy(frames num: 392)
# processed: F0197_01_37851_Android_nexus.npy(frames num: 432)
# processed: M0002_01_4351796082_iPhone_6s.npy(frames num: 497)
# processed: F0157_03_62045_iPhone_iphone6.npy(frames num: 348)
# processed: F0073_02_10574_Android_nexus.npy(frames num: 356)
# processed: M0071_03_62045_iPhone_iphone6.npy(frames num: 314)
# processed: F0154_01_93602_Android_SM.npy(frames num: 382)
# processed: F0182_03_62045_iPhone_iphone6.npy(frames num: 348)
# processed: M0037_03_23895_Android_SM_Gal_J3.npy(frames num: 236)
# processed: F0020_02_4029763518_iPhone_iphone6.npy(frames num: 602)
# processed: F0011_02_4067593812_Android_htc.npy(frames num: 670)
# processed: F0015_03_74126_Android_nexus.npy(frames num: 367)
# processed: M0077_01_61579_iPhone_6s.npy(frames num: 399)
# processed: F0182_01_5837609142_iPhone_6s.npy(frames num: 616)
# processed: F0175_02_50217_Android_nexus.npy(frames num: 257)
# processed: F0200_03_83971_iPhone_iphone6.npy(frames num: 296)
# processed: M0048_02_9730581624_Android_htc.npy(frames num: 490)
# processed: F0200_03_58914_Android_htc.npy(frames num: 358)
# processed: F0119_01_15698_Android_SM.npy(frames num: 287)
# processed: M0079_03_19624_iPhone_6s.npy(frames num: 245)
# processed: F0050_03_53067_Android_SM.npy(frames num: 436)
# processed: F0020_03_1429067358_iPhone_6s.npy(frames num: 573)
# processed: M0067_01_4523869701_iPhone_6s.npy(frames num: 786)
# processed: M0059_02_1392408567_iPhone_iphone6.npy(frames num: 763)
# processed: F0175_03_1025739486_Android_SM.npy(frames num: 405)
# processed: F0168_01_4290583176_Android_SM.npy(frames num: 384)
# processed: M0002_01_25981_iPhone_6s.npy(frames num: 325)
# processed: M0030_03_56307_iPhone_6s.npy(frames num: 379)
# processed: M0083_02_83172_Android_nexus.npy(frames num: 164)
# processed: M0046_01_1698075324_Android_htc.npy(frames num: 757)
# processed: F0005_03_8795106423_Android_nexus.npy(frames num: 481)
# processed: F0090_03_0793286541_Android_SM.npy(frames num: 816)
# processed: F0117_03_18246_Android_SM_Gal_J3.npy(frames num: 255)
# processed: F0052_02_40689_Android_htc.npy(frames num: 342)
# processed: M0039_03_41628_Android_nexus.npy(frames num: 387)
# processed: M0047_03_69570_Android_SM_Gal_J3.npy(frames num: 307)
# processed: M0038_03_41235_Android_SM.npy(frames num: 350)
# processed: M0049_02_2691345807_Android_htc.npy(frames num: 553)
# processed: F0201_01_25103_Android_SM.npy(frames num: 292)
# processed: M0046_02_29845_Android_htc.npy(frames num: 351)
# processed: F0073_02_53417_Android_SM_Gal_J3.npy(frames num: 338)
# processed: M0039_01_9375620841_iPhone_Iphone5.npy(frames num: 685)
# processed: M0028_02_21706_iPhone_Iphone5.npy(frames num: 311)
# processed: F0032_01_70531_iPhone_Iphone5.npy(frames num: 371)
# processed: M0064_03_9156438702_Android_htc.npy(frames num: 581)
# processed: M0072_02_2104796583_Android_SM_Gal_J3.npy(frames num: 689)
# processed: F0173_01_4923510687_Android_SM.npy(frames num: 405)
# processed: F0173_01_87046_iPhone_6s.npy(frames num: 226)
# processed: M0026_02_1306459728_Android_SM.npy(frames num: 512)
# processed: M0088_02_4361825097_Android_SM_Gal_J3.npy(frames num: 626)
# processed: F0051_03_72690_Android_nexus.npy(frames num: 327)
# processed: F0032_01_98264_iPhone_Iphone5.npy(frames num: 412)
# processed: F0191_03_2738015469_iPhone_iphone6.npy(frames num: 445)
# processed: F0042_01_0594267381_Android_htc.npy(frames num: 506)
# processed: F0181_02_5926870431_Android_nexus.npy(frames num: 497)
# processed: F0201_03_98320_Android_SM_Gal_J3.npy(frames num: 247)
# processed: M0036_03_1230694587_Android_SM.npy(frames num: 587)
# processed: F0034_02_4029763518_iPhone_iphone6.npy(frames num: 598)
# processed: M0079_01_03716_iPhone_6s.npy(frames num: 289)
# processed: M0001_03_70315_Android_nexus.npy(frames num: 609)
# processed: M0059_02_4029763518_iPhone_iphone6.npy(frames num: 736)
# processed: M0007_02_58701_Android_SM_Gal_J3.npy(frames num: 384)
# processed: M0053_02_5397410268_iPhone_6s.npy(frames num: 475)
# processed: F0061_03_3297015684_Android_htc.npy(frames num: 727)
# processed: M0056_02_4029763518_iPhone_iphone6.npy(frames num: 471)
# processed: M0030_03_42561_Android_SM.npy(frames num: 318)
# processed: M0041_01_0594267381_Android_htc.npy(frames num: 595)
# processed: M0062_03_83971_iPhone_iphone6.npy(frames num: 302)
# processed: M0059_02_4067593812_Android_htc.npy(frames num: 590)
# processed: M0057_01_23679_iPhone_6s.npy(frames num: 407)
# processed: M0058_01_43652_iPhone_6s.npy(frames num: 427)
# processed: F0010_02_6780524931_Android_htc.npy(frames num: 590)
# processed: F0201_02_75896_Android_htc.npy(frames num: 357)
# processed: F0117_03_3647285901_Android_nexus.npy(frames num: 452)
# processed: F0199_01_98560_Android_SM_Gal_J3.npy(frames num: 196)
# processed: F0034_03_9385741620_Android_SM_Gal_J3.npy(frames num: 698)
# processed: F0051_02_1894372056_iPhone_iphone6.npy(frames num: 550)
# processed: M0028_03_5873419602_Android_nexus.npy(frames num: 493)
# processed: M0072_02_4602935718_Android_nexus.npy(frames num: 669)
# processed: M0060_02_3017568429_Android_nexus.npy(frames num: 575)
# processed: M0006_03_89462_Android_nexus.npy(frames num: 340)
# processed: M0088_01_70968_Android_SM.npy(frames num: 428)
# processed: M0002_03_74126_Android_nexus.npy(frames num: 427)
# processed: M0053_02_21094_iPhone_6s.npy(frames num: 372)
# processed: F0022_03_6574019823_Android_SM.npy(frames num: 445)
# processed: M0053_01_23679_iPhone_6s.npy(frames num: 227)
# processed: F0117_03_79261_Android_nexus.npy(frames num: 271)
# processed: F0010_03_03685_Android_SM.npy(frames num: 315)
# processed: M0055_01_48150_iPhone_6s.npy(frames num: 424)
# processed: M0058_02_42365_iPhone_iphone6.npy(frames num: 362)
# processed: M0076_02_10694_Android_SM_Gal_J3.npy(frames num: 246)
# processed: F0034_03_04238_Android_SM_Gal_J3.npy(frames num: 382)
# processed: M0058_03_18572_Android_nexus.npy(frames num: 371)
# processed: M0033_03_14769_Android_SM_Gal_J3.npy(frames num: 377)
# processed: F0181_01_18465_iPhone_6s.npy(frames num: 310)
# processed: M0001_02_6803471295_Android_SM.npy(frames num: 1202)
# processed: F0182_02_3510748629_Android_nexus.npy(frames num: 535)
# processed: M0070_02_03271_Android_nexus.npy(frames num: 311)
# processed: M0028_02_59021_Android_htc.npy(frames num: 385)
# processed: F0119_02_8567234190_Android_SM_Gal_J3.npy(frames num: 553)
# processed: M0047_01_9108765423_iPhone_Iphone5.npy(frames num: 502)
# processed: F0154_03_18970_Android_SM_Gal_J3.npy(frames num: 437)
# processed: M0002_02_17658_Android_htc.npy(frames num: 369)
# processed: M0043_01_4802765319_Android_htc.npy(frames num: 430)
# processed: F0197_01_26094_Android_nexus.npy(frames num: 445)
# processed: M0057_03_1025739486_Android_SM.npy(frames num: 625)
# processed: F0032_02_74681_Android_htc.npy(frames num: 391)
# processed: F0068_02_5692438017_Android_SM_Gal_J3.npy(frames num: 824)
# processed: M0053_03_5607924138_Android_SM.npy(frames num: 548)
# processed: M0062_01_2593068741_iPhone_6s.npy(frames num: 596)
# processed: M0072_01_23985_iPhone_6s.npy(frames num: 327)
# processed: F0035_01_41853_iPhone_Iphone5.npy(frames num: 359)
# processed: M0082_02_7963108245_Android_nexus.npy(frames num: 527)
# processed: M0013_03_69570_Android_SM_Gal_J3.npy(frames num: 376)
# processed: F0090_01_45213_Android_SM.npy(frames num: 541)
# processed: M0013_02_5064821793_Android_htc.npy(frames num: 837)
# processed: F0200_01_3621475890_Android_nexus.npy(frames num: 662)
# processed: M0041_01_62795_iPhone_Iphone5.npy(frames num: 310)
# processed: F0130_01_8521607493_Android_SM.npy(frames num: 544)
# processed: M0045_01_4802765319_Android_htc.npy(frames num: 878)
# processed: F0175_01_7419068325_iPhone_6s.npy(frames num: 465)
# processed: F0035_03_6987543021_Android_SM_Gal_J3.npy(frames num: 526)
# processed: F0181_01_9856243017_Android_SM.npy(frames num: 563)
# processed: M0083_02_10694_Android_SM_Gal_J3.npy(frames num: 179)
# processed: F0172_01_4290583176_Android_SM.npy(frames num: 425)
# processed: M0065_02_41693_Android_nexus.npy(frames num: 404)
# processed: M0028_02_5213840967_Android_htc.npy(frames num: 505)
# processed: F0199_02_42365_iPhone_iphone6.npy(frames num: 275)
# processed: F0061_03_79845_Android_htc.npy(frames num: 366)
# processed: M0082_03_02764_Android_htc.npy(frames num: 408)
# processed: M0007_01_25981_iPhone_6s.npy(frames num: 428)
# processed: F0005_03_5897106423_Android_SM_Gal_J3.npy(frames num: 427)
# processed: F0005_01_4351796082_iPhone_6s.npy(frames num: 546)
# processed: M0049_03_17983_Android_nexus.npy(frames num: 317)
# processed: F0051_01_2637015489_iPhone_6s.npy(frames num: 460)
# processed: F0021_03_6574019823_Android_SM.npy(frames num: 443)
# processed: F0068_01_2593068741_iPhone_6s.npy(frames num: 829)
# processed: F0095_01_70968_Android_SM.npy(frames num: 440)
# processed: F0042_02_42365_iPhone_iphone6.npy(frames num: 307)
# processed: F0173_02_04279_iPhone_iphone6.npy(frames num: 212)
# processed: F0169_01_4290583176_Android_SM.npy(frames num: 848)
# processed: M0059_01_48150_iPhone_6s.npy(frames num: 873)
# processed: M0060_03_6382975401_Android_htc.npy(frames num: 614)
# processed: M0038_01_62795_iPhone_Iphone5.npy(frames num: 375)
# processed: F0061_01_9872615403_iPhone_6s.npy(frames num: 745)
# processed: M0067_03_97642_Android_htc.npy(frames num: 519)
# processed: F0199_02_9416235780_Android_htc.npy(frames num: 474)
# processed: M0062_03_02764_Android_htc.npy(frames num: 266)
# processed: M0012_01_70216_iPhone_6s.npy(frames num: 310)
# processed: F0011_03_8795106423_Android_nexus.npy(frames num: 597)
# processed: M0059_01_43652_iPhone_6s.npy(frames num: 515)
# processed: F0052_03_60475_iPhone_6s.npy(frames num: 176)
# processed: F0051_01_23679_iPhone_6s.npy(frames num: 314)
# processed: M0078_02_95408_Android_SM_Gal_J3.npy(frames num: 264)
# processed: M0037_02_90864_Android_htc.npy(frames num: 264)
# processed: M0074_03_1247093658_Android_SM.npy(frames num: 506)
# processed: F0117_01_4012579836_Android_SM.npy(frames num: 532)
# processed: M0075_02_07429_Android_nexus.npy(frames num: 437)
# processed: F0034_03_96157_Android_SM_Gal_J3.npy(frames num: 369)
# processed: M0081_02_37528_Android_SM_Gal_J3.npy(frames num: 290)
# processed: F0005_03_89462_Android_nexus.npy(frames num: 263)
# processed: F0021_02_51386_iPhone_iphone6.npy(frames num: 332)
# processed: M0082_03_9075642813_Android_htc.npy(frames num: 626)
# processed: F0191_01_4059286173_Android_SM.npy(frames num: 514)
# processed: F0073_02_1530482697_Android_nexus.npy(frames num: 585)
# processed: M0004_03_4306759182_Android_SM_Gal_J3.npy(frames num: 715)
# processed: F0050_03_64738_iPhone_6s.npy(frames num: 425)
# processed: M0049_02_1392408567_iPhone_iphone6.npy(frames num: 600)
# processed: F0199_02_1392408567_iPhone_iphone6.npy(frames num: 452)
# processed: F0011_03_5734802691_Android_nexus.npy(frames num: 630)
# processed: F0172_02_04279_iPhone_iphone6.npy(frames num: 199)
# processed: M0070_02_8719463205_Android_SM_Gal_J3.npy(frames num: 476)
# processed: M0055_02_29640_Android_htc.npy(frames num: 531)
# processed: M0016_02_1763092458_iPhone_Iphone5.npy(frames num: 826)
# processed: F0050_02_4029763518_iPhone_iphone6.npy(frames num: 688)
# processed: M0053_02_16058_iPhone_6s.npy(frames num: 238)
# processed: M0046_02_16073_Android_htc.npy(frames num: 342)
# processed: M0075_02_16094_Android_nexus.npy(frames num: 495)
# processed: M0049_01_43028_Android_htc.npy(frames num: 372)
# processed: M0038_03_7916423508_iPhone_6s.npy(frames num: 547)
# processed: M0074_02_38907_Android_SM.npy(frames num: 248)
# processed: F0051_02_9730581624_Android_htc.npy(frames num: 537)
# processed: F0169_01_4895126037_iPhone_6s.npy(frames num: 812)
# processed: M0001_03_39685_Android_nexus.npy(frames num: 638)
# processed: M0078_01_2765304981_iPhone_6s.npy(frames num: 502)
# processed: M0033_02_1392408567_iPhone_iphone6.npy(frames num: 641)
# processed: M0078_02_67324_Android_SM_Gal_J3.npy(frames num: 275)
# processed: M0036_03_7863451209_Android_SM.npy(frames num: 503)
# processed: M0041_01_48217_Android_htc.npy(frames num: 438)
# processed: M0002_02_51386_iPhone_iphone6.npy(frames num: 323)
# processed: M0055_02_9730581624_Android_htc.npy(frames num: 838)
# processed: M0004_01_63470_iPhone_6s.npy(frames num: 464)
# processed: M0064_01_70296_iPhone_6s.npy(frames num: 323)
# processed: F0200_01_28701_Android_SM_Gal_J3.npy(frames num: 353)
# processed: F0200_01_98560_Android_SM_Gal_J3.npy(frames num: 347)
# processed: F0032_03_1854329706_iPhone_6s.npy(frames num: 691)
# processed: M0070_03_79428_iPhone_iphone6.npy(frames num: 303)
# processed: M0075_01_6527480931_iPhone_6s.npy(frames num: 837)
# processed: M0007_02_4057961832_Android_nexus.npy(frames num: 647)
# processed: F0042_03_54329_Android_nexus.npy(frames num: 249)
# processed: F0042_02_89071_iPhone_iphone6.npy(frames num: 335)
# processed: F0130_02_27504_Android_nexus.npy(frames num: 213)
# processed: F0201_01_86794_Android_SM.npy(frames num: 280)
# processed: M0059_01_5326071948_iPhone_6s.npy(frames num: 698)
# processed: M0037_01_9064728153_iPhone_Iphone5.npy(frames num: 673)
# processed: F0154_03_53970_Android_SM_Gal_J3.npy(frames num: 394)
# processed: M0046_01_9108765423_iPhone_Iphone5.npy(frames num: 584)
# processed: M0064_01_9872615403_iPhone_6s.npy(frames num: 547)
# processed: M0056_01_43652_iPhone_6s.npy(frames num: 234)
# processed: F0035_03_14682_Android_SM_Gal_J3.npy(frames num: 284)
# processed: F0173_03_06834_Android_SM.npy(frames num: 241)
# processed: M0076_03_2738015469_iPhone_iphone6.npy(frames num: 439)
# processed: F0022_03_2107835946_iPhone_6s.npy(frames num: 512)
# processed: M0065_03_51983_Android_htc.npy(frames num: 369)
# processed: M0081_03_83971_iPhone_iphone6.npy(frames num: 298)
# processed: M0089_01_3702149568_Android_SM.npy(frames num: 855)
# processed: F0061_01_41853_iPhone_6s.npy(frames num: 448)
# processed: F0022_03_56307_iPhone_6s.npy(frames num: 288)
# processed: F0199_03_72039_Android_SM_Gal_J3.npy(frames num: 185)
# processed: M0058_03_9263507184_Android_nexus.npy(frames num: 745)
# processed: M0072_03_26738_Android_htc.npy(frames num: 372)
# processed: M0060_03_08153_Android_htc.npy(frames num: 384)
# processed: M0047_03_4306759182_Android_SM_Gal_J3.npy(frames num: 452)
# processed: M0058_02_1894372056_iPhone_iphone6.npy(frames num: 733)
# processed: M0088_02_6284937150_Android_nexus.npy(frames num: 474)
# processed: F0169_03_29518_Android_SM_Gal_J3.npy(frames num: 474)
# processed: F0191_03_4563207981_Android_htc.npy(frames num: 533)
# processed: F0090_03_7130859426_Android_SM.npy(frames num: 732)
# processed: M0079_01_89524_iPhone_6s.npy(frames num: 310)
# processed: M0033_02_42365_iPhone_iphone6.npy(frames num: 402)
# processed: M0053_02_0673941258_Android_SM.npy(frames num: 466)
# processed: M0059_03_6987543021_Android_SM_Gal_J3.npy(frames num: 685)
# processed: M0076_01_6527480931_iPhone_6s.npy(frames num: 519)
# processed: F0032_02_1392408567_iPhone_iphone6.npy(frames num: 622)
# processed: M0037_02_4029763518_iPhone_iphone6.npy(frames num: 624)
# processed: F0073_02_1397860254_Android_SM_Gal_J3.npy(frames num: 642)
# processed: M0043_02_59021_Android_htc.npy(frames num: 186)
# processed: M0067_03_2738015469_iPhone_iphone6.npy(frames num: 964)
# processed: M0006_03_5734802691_Android_nexus.npy(frames num: 390)
# processed: M0004_01_9761823504_iPhone_6s.npy(frames num: 698)
# processed: M0007_01_1324670895_iPhone_6s.npy(frames num: 624)
# processed: M0076_02_37528_Android_SM_Gal_J3.npy(frames num: 241)
# processed: M0077_03_5823604197_iPhone_6s.npy(frames num: 846)
# processed: M0002_02_4029763518_iPhone_iphone6.npy(frames num: 573)
# processed: F0154_01_28376_iPhone_6s.npy(frames num: 324)
# processed: F0005_03_34786_Android_SM_Gal_J3.npy(frames num: 280)
# processed: F0095_01_3702149568_Android_SM.npy(frames num: 795)
# processed: M0059_01_87901_iPhone_6s.npy(frames num: 539)
# processed: F0069_02_21845_Android_nexus.npy(frames num: 227)
# processed: F0181_01_51783_Android_SM.npy(frames num: 298)
# processed: F0168_03_07516_Android_htc.npy(frames num: 274)
# processed: M0053_03_6412975803_iPhone_6s.npy(frames num: 462)
# processed: F0154_03_9263507184_Android_nexus.npy(frames num: 727)
# processed: F0010_03_39046_Android_SM.npy(frames num: 305)
# processed: F0119_03_30275_Android_SM.npy(frames num: 286)
# processed: M0067_02_8643201957_Android_nexus.npy(frames num: 803)
# processed: F0051_01_87901_iPhone_6s.npy(frames num: 339)
# processed: F0172_01_85346_Android_SM.npy(frames num: 274)
# processed: M0058_02_4029763518_iPhone_iphone6.npy(frames num: 675)
# processed: F0032_02_42365_iPhone_iphone6.npy(frames num: 376)
# processed: M0081_01_4789306251_iPhone_6s.npy(frames num: 424)
# processed: F0068_03_62045_iPhone_iphone6.npy(frames num: 403)
# processed: F0182_02_50217_Android_nexus.npy(frames num: 340)
# processed: M0039_01_0594267381_Android_htc.npy(frames num: 802)
# processed: F0172_02_25647_Android_htc.npy(frames num: 298)
# processed: M0059_02_9730581624_Android_htc.npy(frames num: 628)
# processed: M0046_02_42365_iPhone_iphone6.npy(frames num: 349)
# processed: F0172_03_2870546319_Android_SM_Gal_J3.npy(frames num: 400)
# processed: F0015_03_1532879406_Android_SM_Gal_J3.npy(frames num: 548)
# processed: F0029_02_1392408567_iPhone_iphone6.npy(frames num: 641)
# processed: F0182_02_94863_Android_nexus.npy(frames num: 386)
# processed: F0173_03_3652019748_Android_SM.npy(frames num: 379)
# processed: F0152_01_0435891276_iPhone_6s.npy(frames num: 527)
# processed: F0011_02_51386_iPhone_iphone6.npy(frames num: 450)
# processed: M0004_02_42365_iPhone_iphone6.npy(frames num: 442)
# processed: F0031_02_04279_iPhone_iphone6.npy(frames num: 486)
# processed: M0006_03_6879204135_Android_nexus.npy(frames num: 428)
# processed: F0152_01_76853_Android_SM.npy(frames num: 291)
# processed: M0036_03_7916423508_iPhone_6s.npy(frames num: 497)
# processed: F0168_03_5379128046_Android_htc.npy(frames num: 441)
# processed: F0011_03_12763_Android_SM_Gal_J3.npy(frames num: 418)
# processed: F0197_03_60148_Android_htc.npy(frames num: 447)
# processed: F0011_01_25981_iPhone_6s.npy(frames num: 510)
# processed: M0007_02_9814052673_Android_SM_Gal_J3.npy(frames num: 616)
# processed: F0119_02_27504_Android_nexus.npy(frames num: 296)
# processed: F0172_01_7902154638_Android_SM.npy(frames num: 514)
# processed: M0059_03_53970_Android_SM_Gal_J3.npy(frames num: 363)
# processed: M0026_02_4987305216_Android_SM.npy(frames num: 505)
# processed: M0054_02_4029763518_iPhone_iphone6.npy(frames num: 775)
# processed: F0034_03_53980_Android_nexus.npy(frames num: 425)
# processed: M0036_01_98264_iPhone_Iphone5.npy(frames num: 296)
# processed: M0060_03_9308247615_Android_htc.npy(frames num: 640)
# processed: M0047_03_84312_Android_SM_Gal_J3.npy(frames num: 345)
# processed: M0037_02_04279_iPhone_iphone6.npy(frames num: 287)
# processed: M0056_02_4067593812_Android_htc.npy(frames num: 339)
# processed: M0056_03_7542063198_Android_SM.npy(frames num: 394)
# processed: F0191_02_5926870431_Android_nexus.npy(frames num: 450)
# processed: M0064_02_50782_Android_nexus.npy(frames num: 276)
# processed: M0058_03_2870546319_Android_SM_Gal_J3.npy(frames num: 660)
# processed: F0200_03_2738015469_iPhone_iphone6.npy(frames num: 513)
# processed: F0119_03_5179083462_iPhone_6s.npy(frames num: 546)
# processed: M0001_01_9761823504_iPhone_6s.npy(frames num: 1113)
# processed: M0055_02_89071_iPhone_iphone6.npy(frames num: 437)
# processed: M0060_02_7804526931_Android_nexus.npy(frames num: 612)
# processed: M0089_03_9156438702_Android_htc.npy(frames num: 841)
# processed: F0031_02_1894372056_iPhone_iphone6.npy(frames num: 640)
# processed: M0062_01_70296_iPhone_6s.npy(frames num: 279)
# processed: F0154_01_54109_iPhone_6s.npy(frames num: 361)
# processed: F0191_03_21057_Android_htc.npy(frames num: 345)
# processed: M0006_02_4067593812_Android_htc.npy(frames num: 446)
# processed: F0172_01_29351_iPhone_6s.npy(frames num: 226)
# processed: F0154_02_1392408567_iPhone_iphone6.npy(frames num: 673)
# processed: F0020_03_46972_Android_SM.npy(frames num: 302)
# processed: F0199_03_1463925078_Android_SM_Gal_J3.npy(frames num: 614)
# processed: M0006_01_70216_iPhone_6s.npy(frames num: 297)
# processed: F0035_02_51386_iPhone_iphone6.npy(frames num: 325)
# processed: F0169_02_89071_iPhone_iphone6.npy(frames num: 388)
# processed: F0173_03_53067_Android_SM.npy(frames num: 211)
# processed: F0175_03_9801763425_iPhone_6s.npy(frames num: 425)
# processed: M0007_02_07429_Android_nexus.npy(frames num: 472)
# processed: F0200_03_4532091867_iPhone_iphone6.npy(frames num: 586)
# processed: M0057_02_4731085629_Android_SM_Gal_J3.npy(frames num: 647)
# processed: M0082_03_79428_iPhone_iphone6.npy(frames num: 465)
# processed: F0034_03_71638_Android_nexus.npy(frames num: 436)
# processed: M0030_01_98264_iPhone_Iphone5.npy(frames num: 339)
# processed: F0119_03_8631509472_Android_SM.npy(frames num: 497)
# processed: M0062_03_6382074195_iPhone_iphone6.npy(frames num: 515)
# processed: M0049_03_2543781960_Android_nexus.npy(frames num: 513)
# processed: F0034_01_2593068741_iPhone_Iphone5.npy(frames num: 637)
# processed: F0061_02_03271_Android_nexus.npy(frames num: 362)
# processed: F0027_02_29507_iPhone_Iphone5.npy(frames num: 300)
# processed: F0157_03_82493_Android_htc.npy(frames num: 388)
# processed: F0061_02_5692438017_Android_SM_Gal_J3.npy(frames num: 707)
# processed: F0061_01_70296_iPhone_6s.npy(frames num: 427)
# processed: M0048_02_51386_iPhone_iphone6.npy(frames num: 284)
# processed: M0037_03_91267_Android_SM_Gal_J3.npy(frames num: 360)
# processed: M0077_01_28304_iPhone_6s.npy(frames num: 386)
# processed: F0021_02_89071_iPhone_iphone6.npy(frames num: 352)
# processed: M0074_03_2431650987_iPhone_6s.npy(frames num: 499)
# processed: F0010_03_27351_iPhone_6s.npy(frames num: 301)
# processed: F0009_02_04279_iPhone_iphone6.npy(frames num: 290)
# processed: F0175_03_03984_Android_SM.npy(frames num: 242)
# processed: M0060_03_79428_iPhone_iphone6.npy(frames num: 264)
# processed: F0042_01_48217_Android_htc.npy(frames num: 377)
# processed: F0154_01_0435891276_iPhone_6s.npy(frames num: 613)
# processed: F0172_03_2543781960_Android_nexus.npy(frames num: 381)
# processed: F0152_01_90513_iPhone_6s.npy(frames num: 289)
# processed: M0072_02_83172_Android_nexus.npy(frames num: 322)
# processed: F0173_02_6374801259_Android_htc.npy(frames num: 454)
# processed: F0027_02_8175960234_iPhone_Iphone5.npy(frames num: 615)
# processed: F0201_01_07589_iPhone_6s.npy(frames num: 260)
# processed: M0041_02_64019_Android_SM.npy(frames num: 310)
# processed: M0070_02_74096_Android_SM_Gal_J3.npy(frames num: 303)
# processed: F0073_03_6382074195_iPhone_iphone6.npy(frames num: 464)
# processed: M0038_03_09687_Android_SM.npy(frames num: 354)
# processed: F0197_02_4736850219_iPhone_6s.npy(frames num: 922)
# processed: M0007_02_1906745283_Android_nexus.npy(frames num: 552)
# processed: M0026_03_7130859426_Android_SM.npy(frames num: 415)
# processed: F0152_03_58601_Android_SM.npy(frames num: 215)
# processed: F0130_01_9358406721_Android_SM.npy(frames num: 549)
# processed: M0039_02_5064821793_Android_htc.npy(frames num: 747)
# processed: F0042_01_62795_iPhone_Iphone5.npy(frames num: 365)
# processed: F0035_02_1392408567_iPhone_iphone6.npy(frames num: 549)
# processed: F0154_02_4029763518_iPhone_iphone6.npy(frames num: 652)
# processed: M0088_01_03156_Android_SM.npy(frames num: 277)
# processed: F0031_02_95230_Android_htc.npy(frames num: 441)
# processed: M0055_03_20174_Android_nexus.npy(frames num: 458)
# processed: M0030_02_5037649281_Android_htc.npy(frames num: 542)
# processed: F0200_03_1879354602_Android_htc.npy(frames num: 562)
# processed: M0077_02_3186450927_Android_SM_Gal_J3.npy(frames num: 828)
# processed: M0016_03_5267981034_iPhone_6s.npy(frames num: 788)
# processed: M0056_02_57049_Android_htc.npy(frames num: 234)
# processed: M0060_02_21845_Android_nexus.npy(frames num: 358)
# processed: M0071_02_05469_Android_nexus.npy(frames num: 255)
# processed: M0056_01_5326071948_iPhone_6s.npy(frames num: 461)
# processed: M0046_01_82310_iPhone_Iphone5.npy(frames num: 375)
# processed: F0042_03_84312_Android_SM_Gal_J3.npy(frames num: 273)
# processed: M0002_02_0578342619_Android_htc.npy(frames num: 582)
# processed: M0072_01_2765304981_iPhone_6s.npy(frames num: 651)
# processed: M0037_03_9015826743_Android_SM_Gal_J3.npy(frames num: 568)
# processed: M0053_03_80426_Android_SM.npy(frames num: 227)
# processed: M0053_02_37658_iPhone_6s.npy(frames num: 233)
# processed: M0072_02_8719463205_Android_SM_Gal_J3.npy(frames num: 707)
# processed: M0070_03_53061_iPhone_iphone6.npy(frames num: 200)
# processed: F0069_02_3017568429_Android_nexus.npy(frames num: 371)
# processed: M0038_01_38041_iPhone_Iphone5.npy(frames num: 346)
# processed: M0057_02_57490_Android_SM_Gal_J3.npy(frames num: 297)
# processed: M0036_03_43160_iPhone_6s.npy(frames num: 224)
# processed: M0037_01_43876_iPhone_Iphone5.npy(frames num: 325)
# processed: M0028_03_9385741620_Android_SM_Gal_J3.npy(frames num: 414)
# processed: M0072_02_49586_Android_nexus.npy(frames num: 350)
# processed: F0073_01_2765304981_iPhone_6s.npy(frames num: 551)
# processed: M0089_02_2760493815_Android_SM_Gal_J3.npy(frames num: 748)
# processed: M0036_02_23157_Android_htc.npy(frames num: 282)
# processed: F0051_03_1832965470_Android_SM_Gal_J3.npy(frames num: 490)
# processed: F0173_02_25647_Android_htc.npy(frames num: 186)
# processed: F0173_01_72901_Android_SM.npy(frames num: 237)
# processed: M0088_02_5621079348_Android_nexus.npy(frames num: 543)
# processed: M0059_03_46025_Android_nexus.npy(frames num: 416)
# processed: F0157_03_79428_iPhone_iphone6.npy(frames num: 412)
# processed: M0016_03_91605_iPhone_6s.npy(frames num: 473)
# processed: M0088_02_60487_Android_nexus.npy(frames num: 274)
# processed: M0037_02_42365_iPhone_iphone6.npy(frames num: 272)
# processed: F0182_03_3726105984_Android_htc.npy(frames num: 708)
# processed: M0055_03_89462_Android_nexus.npy(frames num: 437)
# processed: M0028_03_14769_Android_SM_Gal_J3.npy(frames num: 369)
# processed: M0049_02_04279_iPhone_iphone6.npy(frames num: 338)
# processed: M0077_01_2765304981_iPhone_6s.npy(frames num: 611)
# processed: M0067_02_7963108245_Android_nexus.npy(frames num: 811)
# processed: M0007_02_58307_Android_SM_Gal_J3.npy(frames num: 401)
# processed: F0073_01_23985_iPhone_6s.npy(frames num: 308)
# processed: M0036_02_1392408567_iPhone_iphone6.npy(frames num: 565)
# processed: F0130_02_69140_Android_SM_Gal_J3.npy(frames num: 288)
# processed: M0001_02_80316_Android_SM.npy(frames num: 570)
# processed: F0117_01_32074_Android_SM.npy(frames num: 364)
# processed: F0032_03_85792_iPhone_6s.npy(frames num: 449)
# processed: M0075_02_19058_Android_SM_Gal_J3.npy(frames num: 438)
# processed: F0090_01_34789_iPhone_6s.npy(frames num: 483)
# processed: F0200_01_26094_Android_nexus.npy(frames num: 366)
# processed: M0058_02_16073_Android_htc.npy(frames num: 362)
# processed: F0068_01_70296_iPhone_6s.npy(frames num: 510)
# processed: M0089_02_68502_Android_SM_Gal_J3.npy(frames num: 422)
# processed: F0090_03_64827_Android_SM.npy(frames num: 449)
# processed: F0154_02_6374801259_Android_htc.npy(frames num: 760)
# processed: F0200_02_8452379610_Android_SM.npy(frames num: 627)
# processed: M0026_03_8107293465_iPhone_6s.npy(frames num: 487)
# processed: M0081_01_65387_iPhone_6s.npy(frames num: 289)
# processed: F0034_01_9872615403_iPhone_Iphone5.npy(frames num: 602)
# processed: F0169_03_7391246805_Android_nexus.npy(frames num: 744)
# processed: M0047_03_1576042983_Android_nexus.npy(frames num: 512)
# processed: F0090_01_6271853904_iPhone_6s.npy(frames num: 846)
# processed: M0076_01_2765304981_iPhone_6s.npy(frames num: 488)
# processed: F0050_02_17360_Android_htc.npy(frames num: 361)
# processed: M0089_02_1268057439_Android_SM_Gal_J3.npy(frames num: 852)
# processed: F0199_01_1052698347_Android_nexus.npy(frames num: 463)
# processed: M0049_02_42365_iPhone_iphone6.npy(frames num: 440)
# processed: F0201_03_1463925078_Android_SM_Gal_J3.npy(frames num: 474)
# processed: M0033_03_42950_Android_nexus.npy(frames num: 455)
# processed: F0032_01_4523869701_iPhone_Iphone5.npy(frames num: 661)
# processed: F0021_02_2174905683_Android_htc.npy(frames num: 519)
# processed: F0069_01_41853_iPhone_6s.npy(frames num: 324)
# processed: M0006_03_8415260937_Android_SM_Gal_J3.npy(frames num: 413)
# processed: M0048_02_17538_Android_htc.npy(frames num: 274)
# processed: M0075_03_7542063198_Android_SM.npy(frames num: 709)
# processed: M0049_01_92135_iPhone_Iphone5.npy(frames num: 261)
# processed: M0013_03_86071_Android_nexus.npy(frames num: 382)
# processed: F0051_01_48150_iPhone_6s.npy(frames num: 529)
# processed: M0047_03_45921_Android_SM_Gal_J3.npy(frames num: 264)
# processed: M0004_03_84312_Android_SM_Gal_J3.npy(frames num: 430)
# processed: F0050_01_1460753928_Android_SM.npy(frames num: 586)
# processed: F0095_03_83971_iPhone_iphone6.npy(frames num: 373)
# processed: M0060_02_50782_Android_nexus.npy(frames num: 374)
# processed: F0157_03_36245_Android_htc.npy(frames num: 355)
# processed: F0061_02_2104796583_Android_SM_Gal_J3.npy(frames num: 677)
# processed: M0059_02_51386_iPhone_iphone6.npy(frames num: 499)
# processed: M0012_03_4306759182_Android_SM_Gal_J3.npy(frames num: 345)
# processed: M0065_01_2593068741_iPhone_6s.npy(frames num: 689)
# processed: F0172_01_87046_iPhone_6s.npy(frames num: 309)
# processed: F0157_01_90513_iPhone_6s.npy(frames num: 385)
# processed: M0043_02_5213840967_Android_htc.npy(frames num: 362)
# processed: F0005_03_8415260937_Android_SM_Gal_J3.npy(frames num: 432)
# processed: M0041_03_64738_iPhone_6s.npy(frames num: 379)
# processed: F0199_03_98320_Android_SM_Gal_J3.npy(frames num: 200)
# processed: F0200_02_5314672908_Android_SM.npy(frames num: 571)
# processed: F0005_03_20174_Android_nexus.npy(frames num: 291)
# processed: F0011_01_63470_iPhone_6s.npy(frames num: 500)
# processed: M0016_02_63148_iPhone_Iphone5.npy(frames num: 415)
# processed: F0117_03_30429_Android_SM_Gal_J3.npy(frames num: 315)
# processed: M0048_02_4029763518_iPhone_iphone6.npy(frames num: 548)
# processed: F0175_03_2594680137_iPhone_6s.npy(frames num: 426)
# processed: F0051_02_62138_Android_htc.npy(frames num: 342)
# processed: M0002_03_7952680314_Android_nexus.npy(frames num: 647)
# processed: F0027_02_63148_iPhone_Iphone5.npy(frames num: 386)
# processed: F0172_02_27348_Android_htc.npy(frames num: 308)
# processed: F0068_02_4602935718_Android_nexus.npy(frames num: 801)
# processed: M0028_02_74681_Android_htc.npy(frames num: 313)
# processed: M0038_03_92706_Android_SM.npy(frames num: 388)
# processed: M0059_03_3142985706_Android_nexus.npy(frames num: 693)
# processed: M0089_01_97842_Android_SM.npy(frames num: 511)
# processed: F0021_02_1392408567_iPhone_iphone6.npy(frames num: 488)
# processed: M0026_02_41320_iPhone_6s.npy(frames num: 335)
# processed: F0200_02_74832_iPhone_6s.npy(frames num: 337)
# processed: F0068_03_6382074195_iPhone_iphone6.npy(frames num: 774)
# processed: F0191_01_86794_Android_SM.npy(frames num: 332)
# processed: M0055_03_6879204135_Android_nexus.npy(frames num: 789)
# processed: F0201_03_49108_Android_nexus.npy(frames num: 259)
# processed: M0060_03_9075642813_Android_htc.npy(frames num: 685)
# processed: M0070_02_4602935718_Android_nexus.npy(frames num: 488)
# processed: F0191_03_62045_iPhone_iphone6.npy(frames num: 276)
# processed: M0062_02_41693_Android_nexus.npy(frames num: 259)
# processed: M0004_01_1324670895_iPhone_6s.npy(frames num: 689)
# processed: M0038_01_51902_iPhone_Iphone5.npy(frames num: 254)
# processed: F0182_02_0938157624_Android_SM_Gal_J3.npy(frames num: 647)
# processed: M0076_01_61579_iPhone_6s.npy(frames num: 275)
# processed: M0001_03_8795106423_Android_nexus.npy(frames num: 1124)
# processed: M0075_02_95408_Android_SM_Gal_J3.npy(frames num: 453)
# processed: F0020_01_43652_iPhone_6s.npy(frames num: 375)
# processed: M0076_02_8719463205_Android_SM_Gal_J3.npy(frames num: 456)
# processed: M0072_03_8726039514_Android_htc.npy(frames num: 695)
# processed: F0182_03_83971_iPhone_iphone6.npy(frames num: 352)
# processed: M0012_02_29845_Android_htc.npy(frames num: 286)
# processed: F0157_01_8021397465_Android_SM.npy(frames num: 687)
# processed: F0021_03_85310_Android_SM.npy(frames num: 287)
# processed: M0037_02_1392408567_iPhone_iphone6.npy(frames num: 583)
# processed: M0046_01_07864_iPhone_Iphone5.npy(frames num: 351)
# processed: F0200_03_30627_Android_htc.npy(frames num: 538)
# processed: F0021_02_42365_iPhone_iphone6.npy(frames num: 310)
# processed: M0055_02_51386_iPhone_iphone6.npy(frames num: 475)
# processed: F0035_02_1253068479_Android_htc.npy(frames num: 604)
# processed: F0119_01_9726431850_Android_SM.npy(frames num: 606)
# processed: M0071_03_79428_iPhone_iphone6.npy(frames num: 311)
# processed: M0067_02_8719463205_Android_SM_Gal_J3.npy(frames num: 909)
# processed: M0026_02_80316_Android_SM.npy(frames num: 340)
# processed: M0016_02_21706_iPhone_Iphone5.npy(frames num: 371)
# processed: M0049_01_04391_Android_htc.npy(frames num: 414)
# processed: M0057_03_32198_iPhone_6s.npy(frames num: 412)
# processed: M0002_01_9761823504_iPhone_6s.npy(frames num: 524)
# processed: M0054_02_9730581624_Android_htc.npy(frames num: 830)
# processed: F0181_01_8076135429_Android_SM.npy(frames num: 567)
# processed: M0065_03_83971_iPhone_iphone6.npy(frames num: 346)
# processed: F0119_03_38750_iPhone_6s.npy(frames num: 302)
# processed: F0029_02_1253068479_Android_htc.npy(frames num: 674)
# processed: F0169_02_41302_Android_htc.npy(frames num: 472)
# processed: F0020_02_1253068479_Android_htc.npy(frames num: 625)
# processed: M0048_01_82310_iPhone_Iphone5.npy(frames num: 267)
# processed: F0068_02_7963108245_Android_nexus.npy(frames num: 880)
# processed: M0064_02_7804526931_Android_nexus.npy(frames num: 548)
# processed: F0154_02_1894372056_iPhone_iphone6.npy(frames num: 778)
# processed: M0013_03_3792846105_Android_nexus.npy(frames num: 772)
# processed: M0049_03_2870546319_Android_SM_Gal_J3.npy(frames num: 651)
# processed: F0154_02_04279_iPhone_iphone6.npy(frames num: 338)
# processed: F0172_01_7419068325_iPhone_6s.npy(frames num: 439)
# processed: M0075_03_02864_iPhone_6s.npy(frames num: 446)
# processed: F0199_03_72486_Android_nexus.npy(frames num: 224)
# processed: F0181_02_94863_Android_nexus.npy(frames num: 236)
# processed: F0021_02_23157_Android_htc.npy(frames num: 294)
# processed: F0090_03_93501_Android_SM.npy(frames num: 418)
# processed: F0090_03_95102_iPhone_6s.npy(frames num: 510)
# processed: F0119_03_31248_iPhone_6s.npy(frames num: 315)
# processed: F0042_02_62138_Android_htc.npy(frames num: 286)
# processed: M0062_02_50782_Android_nexus.npy(frames num: 233)
# processed: M0001_03_34786_Android_SM_Gal_J3.npy(frames num: 784)
# processed: M0004_03_73068_Android_SM_Gal_J3.npy(frames num: 448)
# processed: M0055_03_05849_Android_SM_Gal_J3.npy(frames num: 432)
# processed: F0069_01_9872615403_iPhone_6s.npy(frames num: 625)
# processed: M0074_02_5041896723_Android_SM.npy(frames num: 482)
# processed: M0028_02_95230_Android_htc.npy(frames num: 412)
# processed: M0077_02_05314_Android_SM_Gal_J3.npy(frames num: 470)
# processed: F0052_02_4952670138_Android_htc.npy(frames num: 678)
# processed: F0073_02_01478_Android_SM_Gal_J3.npy(frames num: 346)
# processed: M0026_02_0256481739_iPhone_6s.npy(frames num: 438)
# processed: F0201_02_51386_iPhone_iphone6.npy(frames num: 276)
# processed: F0157_03_83971_iPhone_iphone6.npy(frames num: 372)
# processed: M0033_03_04238_Android_SM_Gal_J3.npy(frames num: 393)
# processed: M0002_02_42365_iPhone_iphone6.npy(frames num: 387)
# processed: M0041_02_3910576824_Android_SM.npy(frames num: 801)
# processed: M0012_03_73068_Android_SM_Gal_J3.npy(frames num: 182)
# processed: F0022_01_8102574936_iPhone_6s.npy(frames num: 510)
# processed: F0051_02_04279_iPhone_iphone6.npy(frames num: 342)
# processed: F0015_03_53980_Android_nexus.npy(frames num: 327)
# processed: M0056_03_9801763425_iPhone_6s.npy(frames num: 434)
# processed: F0073_02_23596_Android_SM_Gal_J3.npy(frames num: 352)
# processed: F0020_02_46783_Android_htc.npy(frames num: 426)
# processed: F0095_01_03156_Android_SM.npy(frames num: 403)
# processed: F0200_02_1438276059_iPhone_6s.npy(frames num: 634)
# processed: F0182_03_36245_Android_htc.npy(frames num: 377)
# processed: F0068_03_4532091867_iPhone_iphone6.npy(frames num: 729)
# processed: F0031_02_51386_iPhone_iphone6.npy(frames num: 403)
# processed: M0053_03_57189_Android_SM.npy(frames num: 224)
# processed: M0062_03_08153_Android_htc.npy(frames num: 287)
# processed: M0007_02_7639814520_Android_nexus.npy(frames num: 599)
# processed: M0088_02_5326987140_Android_SM_Gal_J3.npy(frames num: 538)
# processed: F0011_02_1894372056_iPhone_iphone6.npy(frames num: 637)
# processed: F0175_01_4895126037_iPhone_6s.npy(frames num: 502)
# processed: M0059_02_42365_iPhone_iphone6.npy(frames num: 462)
# processed: M0076_03_9156438702_Android_htc.npy(frames num: 462)
# processed: M0067_03_4532091867_iPhone_iphone6.npy(frames num: 888)
# processed: M0059_03_14682_Android_SM_Gal_J3.npy(frames num: 391)
# processed: M0058_03_3142985706_Android_nexus.npy(frames num: 746)
# processed: F0172_02_6374801259_Android_htc.npy(frames num: 410)
# processed: M0039_02_1894372056_iPhone_iphone6.npy(frames num: 642)
# processed: F0073_03_59708_Android_htc.npy(frames num: 253)
# processed: F0032_03_43160_iPhone_6s.npy(frames num: 437)
# processed: F0175_02_68143_Android_nexus.npy(frames num: 217)
# processed: M0012_01_9761823504_iPhone_6s.npy(frames num: 434)
# processed: M0076_03_53061_iPhone_iphone6.npy(frames num: 211)
# processed: F0200_01_1052698347_Android_nexus.npy(frames num: 644)
# processed: F0090_03_42739_Android_SM.npy(frames num: 402)
# processed: F0022_03_73890_Android_SM.npy(frames num: 413)
# processed: M0037_01_75963_Android_htc.npy(frames num: 314)
# processed: F0032_02_46783_Android_htc.npy(frames num: 377)
# processed: M0001_03_8415260937_Android_SM_Gal_J3.npy(frames num: 1304)
# processed: M0077_03_60475_iPhone_6s.npy(frames num: 488)
# processed: M0055_01_2637015489_iPhone_6s.npy(frames num: 710)
# processed: M0081_03_6382074195_iPhone_iphone6.npy(frames num: 474)
# processed: F0169_02_1392408567_iPhone_iphone6.npy(frames num: 783)
# processed: M0056_02_89071_iPhone_iphone6.npy(frames num: 239)
# processed: M0065_01_70531_iPhone_6s.npy(frames num: 389)
# processed: M0071_03_2738015469_iPhone_iphone6.npy(frames num: 648)
# processed: F0042_03_73068_Android_SM_Gal_J3.npy(frames num: 215)
# processed: F0042_01_9064728153_iPhone_Iphone5.npy(frames num: 523)
# processed: M0082_02_4602935718_Android_nexus.npy(frames num: 510)
# processed: F0200_01_7239856140_Android_SM_Gal_J3.npy(frames num: 606)
# processed: F0182_02_0369245817_Android_nexus.npy(frames num: 612)
# processed: M0076_02_15238_Android_SM_Gal_J3.npy(frames num: 340)
# processed: M0049_03_34690_Android_nexus.npy(frames num: 303)
# processed: M0001_03_5734802691_Android_nexus.npy(frames num: 1061)
# processed: M0012_02_90864_Android_htc.npy(frames num: 224)
# processed: F0061_03_58720_Android_htc.npy(frames num: 462)
# processed: M0060_03_02764_Android_htc.npy(frames num: 417)
# ...
# processed: F0015_02_29150_Android_htc.npy(frames num: 352)
# processed: M0030_03_12948_iPhone_6s.npy(frames num: 310)
# processed: F0201_01_1580647932_Android_SM.npy(frames num: 469)
# processed: F0027_02_1230895746_iPhone_Iphone5.npy(frames num: 737)
# processed: F0050_03_4263107589_iPhone_6s.npy(frames num: 684)
# processed: F0034_02_74681_Android_htc.npy(frames num: 332)
# processed: M0072_03_14590_Android_htc.npy(frames num: 369)
# processed: M0004_02_17360_Android_htc.npy(frames num: 373)
# processed: F0010_01_25981_iPhone_6s.npy(frames num: 421)
# processed: F0197_03_53061_iPhone_iphone6.npy(frames num: 462)
# processed: F0191_01_07589_iPhone_6s.npy(frames num: 364)
# processed: M0070_03_8726039514_Android_htc.npy(frames num: 565)
# processed: M0041_01_4615028739_iPhone_Iphone5.npy(frames num: 503)
# processed: F0119_01_75362_Android_SM.npy(frames num: 265)
# processed: F0197_01_3621475890_Android_nexus.npy(frames num: 989)
# processed: M0033_02_89071_iPhone_iphone6.npy(frames num: 375)
# processed: F0200_01_2837051964_Android_SM_Gal_J3.npy(frames num: 664)
# processed: M0067_01_98264_iPhone_6s.npy(frames num: 387)
# processed: F0117_01_2571963048_Android_SM.npy(frames num: 543)
# processed: M0041_01_08142_Android_htc.npy(frames num: 312)
# processed: M0041_03_12590_iPhone_6s.npy(frames num: 387)
# processed: F0119_02_69140_Android_SM_Gal_J3.npy(frames num: 441)
# processed: M0036_02_51386_iPhone_iphone6.npy(frames num: 350)
# processed: M0089_02_49738_Android_nexus.npy(frames num: 403)
# processed: F0042_01_9375620841_iPhone_Iphone5.npy(frames num: 550)
# processed: M0002_02_2691345807_Android_htc.npy(frames num: 575)
# processed: M0044_01_10854_Android_htc.npy(frames num: 422)
# processed: F0031_01_4523869701_iPhone_Iphone5.npy(frames num: 809)
# processed: F0201_03_4062579138_Android_SM_Gal_J3.npy(frames num: 455)
# processed: M0057_03_60475_iPhone_6s.npy(frames num: 389)
# processed: F0027_03_5267981034_iPhone_6s.npy(frames num: 501)
# processed: M0041_03_3652019748_Android_SM.npy(frames num: 580)
# processed: F0173_03_9327861450_Android_SM.npy(frames num: 437)
# processed: M0072_03_13740_Android_htc.npy(frames num: 374)
# processed: F0015_03_03582_Android_SM_Gal_J3.npy(frames num: 371)
# processed: M0057_02_6594720318_Android_nexus.npy(frames num: 587)
# processed: F0182_01_59146_Android_SM.npy(frames num: 293)
# processed: M0079_03_67059_iPhone_6s.npy(frames num: 263)
# processed: F0027_02_29150_Android_htc.npy(frames num: 294)
# processed: F0073_03_4532091867_iPhone_iphone6.npy(frames num: 498)
# processed: M0041_01_9375620841_iPhone_Iphone5.npy(frames num: 499)
# processed: F0130_03_48721_Android_SM.npy(frames num: 272)
# processed: M0072_02_05469_Android_nexus.npy(frames num: 341)
# processed: M0016_03_46972_Android_SM.npy(frames num: 494)
# processed: M0016_01_48150_iPhone_6s.npy(frames num: 397)
# processed: M0064_03_83971_iPhone_iphone6.npy(frames num: 324)
# processed: F0119_03_2509134786_iPhone_6s.npy(frames num: 535)
# processed: F0157_01_93602_Android_SM.npy(frames num: 340)
# processed: M0053_02_24183_Android_SM.npy(frames num: 258)
# processed: F0169_02_71045_Android_htc.npy(frames num: 474)
# processed: F0119_01_2571963048_Android_SM.npy(frames num: 600)
# processed: F0154_03_17983_Android_nexus.npy(frames num: 397)
# processed: M0065_01_41853_iPhone_6s.npy(frames num: 410)
# processed: M0033_01_9872615403_iPhone_Iphone5.npy(frames num: 500)
# processed: F0051_03_3729158604_Android_SM_Gal_J3.npy(frames num: 474)
# processed: F0027_03_73890_Android_SM.npy(frames num: 310)
# processed: F0035_03_2543781960_Android_nexus.npy(frames num: 609)
# processed: F0052_03_02864_iPhone_6s.npy(frames num: 187)
# processed: M0016_03_42561_Android_SM.npy(frames num: 484)
# processed: M0056_03_31759_iPhone_6s.npy(frames num: 289)
# processed: M0071_03_7629538140_Android_htc.npy(frames num: 522)
# processed: F0200_02_91605_iPhone_6s.npy(frames num: 352)
# processed: F0020_02_5213840967_Android_htc.npy(frames num: 598)
# processed: M0028_03_71638_Android_nexus.npy(frames num: 283)
# processed: M0078_02_25783_Android_nexus.npy(frames num: 300)
# processed: F0095_03_6382074195_iPhone_iphone6.npy(frames num: 698)
# processed: M0079_03_60395_Android_SM.npy(frames num: 272)
# processed: F0011_01_54398_iPhone_6s.npy(frames num: 496)
# processed: M0082_03_4532091867_iPhone_iphone6.npy(frames num: 649)
# processed: M0071_03_53061_iPhone_iphone6.npy(frames num: 271)
# processed: F0010_02_89071_iPhone_iphone6.npy(frames num: 262)
# processed: M0041_01_75963_Android_htc.npy(frames num: 363)
# processed: F0035_02_4029763518_iPhone_iphone6.npy(frames num: 571)
# processed: F0034_01_70531_iPhone_Iphone5.npy(frames num: 265)
# processed: F0011_02_89071_iPhone_iphone6.npy(frames num: 515)
# processed: F0201_03_6482310759_Android_nexus.npy(frames num: 472)
# processed: F0069_03_9075642813_Android_htc.npy(frames num: 440)
# processed: F0201_03_81564_Android_SM_Gal_J3.npy(frames num: 216)
# processed: M0072_03_2738015469_iPhone_iphone6.npy(frames num: 687)
# processed: F0050_03_06834_Android_SM.npy(frames num: 429)
# processed: F0197_02_96235_iPhone_6s.npy(frames num: 562)
# processed: F0069_02_7804526931_Android_nexus.npy(frames num: 381)
# processed: F0117_03_7564281309_Android_nexus.npy(frames num: 487)
# processed: M0044_02_89071_iPhone_iphone6.npy(frames num: 397)
# processed: M0071_01_47016_iPhone_6s.npy(frames num: 272)
# processed: M0041_02_4736850219_iPhone_6s.npy(frames num: 608)
# processed: M0060_03_6382074195_iPhone_iphone6.npy(frames num: 610)
# processed: F0020_03_73284_iPhone_6s.npy(frames num: 361)
# processed: F0200_02_98563_Android_SM.npy(frames num: 324)
# processed: M0038_02_1392408567_iPhone_iphone6.npy(frames num: 751)
# processed: M0045_03_7863451209_Android_SM.npy(frames num: 755)
# processed: F0173_03_5487910236_Android_SM.npy(frames num: 412)
# processed: M0047_02_1723496085_iPhone_6s.npy(frames num: 486)
# processed: F0200_02_89417_iPhone_6s.npy(frames num: 398)
# processed: F0157_01_28376_iPhone_6s.npy(frames num: 412)
# processed: F0117_02_51386_iPhone_iphone6.npy(frames num: 260)
# processed: F0011_02_17538_Android_htc.npy(frames num: 470)
# processed: M0001_03_89462_Android_nexus.npy(frames num: 672)
# processed: F0032_02_59021_Android_htc.npy(frames num: 406)
# processed: F0020_02_1894372056_iPhone_iphone6.npy(frames num: 584)
# processed: F0119_01_6519347208_iPhone_6s.npy(frames num: 562)
# processed: M0048_02_1392408567_iPhone_iphone6.npy(frames num: 515)
# processed: M0081_03_75423_Android_htc.npy(frames num: 298)
# processed: F0032_02_1894372056_iPhone_iphone6.npy(frames num: 657)
# processed: M0056_01_23679_iPhone_6s.npy(frames num: 251)
# processed: M0006_02_1894372056_iPhone_iphone6.npy(frames num: 414)
# processed: F0042_02_4029763518_iPhone_iphone6.npy(frames num: 516)
# processed: F0010_01_70216_iPhone_6s.npy(frames num: 448)
# processed: F0169_03_62418_Android_nexus.npy(frames num: 448)
# processed: M0089_03_14590_Android_htc.npy(frames num: 420)
# processed: M0039_01_51902_iPhone_Iphone5.npy(frames num: 338)
# processed: F0051_03_45921_Android_SM_Gal_J3.npy(frames num: 328)
# processed: M0064_02_97063_Android_nexus.npy(frames num: 299)
# processed: M0038_01_9375620841_iPhone_Iphone5.npy(frames num: 600)
# processed: M0044_01_6918207345_iPhone_Iphone5.npy(frames num: 736)
# processed: F0191_02_50217_Android_nexus.npy(frames num: 283)
# processed: F0061_03_79428_iPhone_iphone6.npy(frames num: 364)
# processed: F0191_01_7096245183_iPhone_6s.npy(frames num: 523)
# processed: M0088_01_34789_iPhone_6s.npy(frames num: 276)
# processed: F0073_01_47016_iPhone_6s.npy(frames num: 260)
# processed: F0200_03_79428_iPhone_iphone6.npy(frames num: 415)
# processed: M0012_01_4351796082_iPhone_6s.npy(frames num: 464)
# processed: M0002_03_9263475180_Android_nexus.npy(frames num: 650)
# processed: F0029_02_74681_Android_htc.npy(frames num: 312)
# processed: F0027_03_56307_iPhone_6s.npy(frames num: 264)
# processed: M0044_01_69047_iPhone_Iphone5.npy(frames num: 328)
# processed: M0016_02_46783_Android_htc.npy(frames num: 434)
# processed: M0039_01_75963_Android_htc.npy(frames num: 452)
# processed: F0010_02_5064821793_Android_htc.npy(frames num: 543)
# processed: M0030_02_1253068479_Android_htc.npy(frames num: 586)
# processed: M0002_03_14769_Android_SM_Gal_J3.npy(frames num: 342)
# processed: F0199_02_04279_iPhone_iphone6.npy(frames num: 285)
# processed: F0157_01_0435891276_iPhone_6s.npy(frames num: 659)
# processed: F0191_01_1580647932_Android_SM.npy(frames num: 529)
# processed: M0076_03_13740_Android_htc.npy(frames num: 241)
# processed: M0054_02_29640_Android_htc.npy(frames num: 447)
# processed: F0052_03_5823604197_iPhone_6s.npy(frames num: 347)
# processed: F0009_03_32780_Android_SM.npy(frames num: 244)
# processed: M0076_02_83172_Android_nexus.npy(frames num: 211)
# processed: M0079_01_4789306251_iPhone_6s.npy(frames num: 428)
# processed: F0051_02_42365_iPhone_iphone6.npy(frames num: 323)
# processed: M0056_03_03984_Android_SM.npy(frames num: 225)
# processed: M0033_01_4523869701_iPhone_Iphone5.npy(frames num: 450)
# processed: F0090_01_24309_iPhone_6s.npy(frames num: 470)
# processed: M0072_03_6382074195_iPhone_iphone6.npy(frames num: 674)
# processed: M0083_01_01294_iPhone_6s.npy(frames num: 133)
# processed: M0002_03_96157_Android_SM_Gal_J3.npy(frames num: 322)
# processed: M0006_03_39685_Android_nexus.npy(frames num: 300)
# processed: M0078_02_4850126937_Android_SM_Gal_J3.npy(frames num: 491)
# processed: F0095_01_34789_iPhone_6s.npy(frames num: 436)
# processed: F0201_03_72486_Android_nexus.npy(frames num: 274)
# processed: M0047_02_73489_iPhone_6s.npy(frames num: 375)
# processed: F0157_03_4532091867_iPhone_iphone6.npy(frames num: 773)
# processed: F0201_01_4059286173_Android_SM.npy(frames num: 481)
# processed: F0015_02_94862_Android_htc.npy(frames num: 259)
# processed: F0068_03_79428_iPhone_iphone6.npy(frames num: 398)
# processed: M0016_02_29507_iPhone_Iphone5.npy(frames num: 385)
# processed: M0012_02_23157_Android_htc.npy(frames num: 214)
# processed: F0181_01_8167295430_iPhone_6s.npy(frames num: 570)
# processed: F0191_02_82673_Android_SM_Gal_J3.npy(frames num: 289)
# processed: F0095_03_4532091867_iPhone_iphone6.npy(frames num: 814)
# processed: M0016_03_56307_iPhone_6s.npy(frames num: 438)
# processed: M0082_02_2104796583_Android_SM_Gal_J3.npy(frames num: 665)
# processed: F0175_02_94863_Android_nexus.npy(frames num: 232)
# processed: M0058_02_89071_iPhone_iphone6.npy(frames num: 386)
# processed: M0030_03_1429067358_iPhone_6s.npy(frames num: 572)
# processed: M0076_02_7963108245_Android_nexus.npy(frames num: 443)
# processed: F0130_01_79284_Android_SM.npy(frames num: 286)
# processed: M0016_02_8175960234_iPhone_Iphone5.npy(frames num: 721)
# processed: F0090_01_7458109632_Android_SM.npy(frames num: 903)
# processed: F0117_02_89254_Android_htc.npy(frames num: 245)
# processed: F0021_01_5326071948_iPhone_6s.npy(frames num: 500)
# processed: M0030_02_74681_Android_htc.npy(frames num: 454)
# processed: M0075_03_60475_iPhone_6s.npy(frames num: 415)
# processed: F0090_01_65718_iPhone_6s.npy(frames num: 474)
# processed: F0191_03_39752_Android_htc.npy(frames num: 333)
# processed: F0035_03_2687041593_Android_SM_Gal_J3.npy(frames num: 573)
# processed: F0173_01_0768123549_iPhone_6s.npy(frames num: 424)
# processed: M0081_02_8719463205_Android_SM_Gal_J3.npy(frames num: 494)
# processed: F0034_02_59021_Android_htc.npy(frames num: 292)
# processed: M0039_03_06931_Android_nexus.npy(frames num: 395)
# processed: F0011_02_42365_iPhone_iphone6.npy(frames num: 476)
# processed: F0011_03_05849_Android_SM_Gal_J3.npy(frames num: 369)
# processed: M0048_02_62138_Android_htc.npy(frames num: 313)
# processed: F0172_03_34690_Android_nexus.npy(frames num: 225)
# processed: F0117_03_5063784192_Android_SM_Gal_J3.npy(frames num: 623)
# processed: M0082_01_01294_iPhone_6s.npy(frames num: 336)
# processed: F0021_01_2637015489_iPhone_6s.npy(frames num: 510)
# processed: F0020_01_8102574936_iPhone_6s.npy(frames num: 647)
# processed: M0053_01_2637015489_iPhone_6s.npy(frames num: 427)
# processed: M0056_02_9730581624_Android_htc.npy(frames num: 450)
# processed: F0119_02_91082_Android_nexus.npy(frames num: 253)
# processed: F0169_01_7419068325_iPhone_6s.npy(frames num: 825)
# processed: M0001_03_5897106423_Android_SM_Gal_J3.npy(frames num: 1186)
# processed: M0065_03_2738015469_iPhone_iphone6.npy(frames num: 636)
# processed: M0060_03_2738015469_iPhone_iphone6.npy(frames num: 499)
# processed: F0157_01_20914_Android_SM.npy(frames num: 376)
# processed: F0009_02_1392408567_iPhone_iphone6.npy(frames num: 486)
# processed: M0055_01_23679_iPhone_6s.npy(frames num: 439)
# processed: M0039_03_91267_Android_SM_Gal_J3.npy(frames num: 332)
# processed: F0035_02_89071_iPhone_iphone6.npy(frames num: 335)
# processed: M0004_02_0582397146_Android_htc.npy(frames num: 630)
# processed: F0009_01_1324670895_iPhone_6s.npy(frames num: 553)
# processed: M0071_03_4563207981_Android_htc.npy(frames num: 540)
# processed: F0020_03_5267981034_iPhone_6s.npy(frames num: 549)
# processed: M0082_02_10694_Android_SM_Gal_J3.npy(frames num: 328)
# processed: F0119_03_19624_iPhone_6s.npy(frames num: 325)
# processed: M0057_02_21409_Android_nexus.npy(frames num: 308)
# processed: M0036_02_90864_Android_htc.npy(frames num: 292)
# processed: M0076_01_7108563429_iPhone_6s.npy(frames num: 564)
# processed: F0050_02_89254_Android_htc.npy(frames num: 416)
# processed: F0069_01_98264_iPhone_6s.npy(frames num: 310)
# processed: M0056_02_51386_iPhone_iphone6.npy(frames num: 202)
# processed: M0076_02_05469_Android_nexus.npy(frames num: 212)
# processed: M0044_02_95230_Android_htc.npy(frames num: 348)
# processed: M0062_03_79428_iPhone_iphone6.npy(frames num: 277)
# processed: F0200_02_81254_Android_SM.npy(frames num: 329)
# processed: M0081_02_03271_Android_nexus.npy(frames num: 226)
# processed: F0154_01_27864_iPhone_6s.npy(frames num: 311)
# processed: M0039_01_39605_Android_htc.npy(frames num: 472)
# processed: M0083_02_15238_Android_SM_Gal_J3.npy(frames num: 220)
# processed: F0031_01_41853_iPhone_Iphone5.npy(frames num: 377)
# processed: F0095_03_2931068574_Android_htc.npy(frames num: 700)
# processed: F0197_02_7608251493_iPhone_6s.npy(frames num: 972)
# processed: F0090_01_3019456782_iPhone_6s.npy(frames num: 836)
# processed: F0052_02_05269_Android_htc.npy(frames num: 324)
# processed: M0045_01_35812_iPhone_Iphone5.npy(frames num: 414)
# processed: M0039_02_29845_Android_htc.npy(frames num: 485)
# processed: M0047_01_1698075324_Android_htc.npy(frames num: 506)
# processed: M0013_02_42365_iPhone_iphone6.npy(frames num: 438)
# processed: M0013_03_84312_Android_SM_Gal_J3.npy(frames num: 417)
# processed: M0004_03_9203745681_Android_nexus.npy(frames num: 707)
# processed: M0043_02_46783_Android_htc.npy(frames num: 305)
# processed: M0072_03_4532091867_iPhone_iphone6.npy(frames num: 673)
# processed: M0081_02_4602935718_Android_nexus.npy(frames num: 529)
# processed: F0020_01_5326071948_iPhone_6s.npy(frames num: 635)
# processed: F0050_01_24789_Android_SM.npy(frames num: 453)
# processed: M0012_03_1576042983_Android_nexus.npy(frames num: 377)
# processed: M0056_01_48150_iPhone_6s.npy(frames num: 232)
# processed: F0172_02_1392408567_iPhone_iphone6.npy(frames num: 351)
# processed: M0055_03_70315_Android_nexus.npy(frames num: 372)
# processed: F0090_01_3702149568_Android_SM.npy(frames num: 939)
# processed: F0029_03_14358_Android_SM.npy(frames num: 373)
# processed: M0065_03_4532091867_iPhone_iphone6.npy(frames num: 598)
# processed: M0089_02_93174_Android_SM_Gal_J3.npy(frames num: 443)
# processed: M0049_03_9263507184_Android_nexus.npy(frames num: 534)
# processed: M0078_01_47016_iPhone_6s.npy(frames num: 338)
# processed: F0119_02_86913_Android_nexus.npy(frames num: 331)
# processed: M0016_03_73284_iPhone_6s.npy(frames num: 490)
# processed: F0011_02_4910725836_Android_htc.npy(frames num: 642)
# processed: F0020_03_73890_Android_SM.npy(frames num: 305)
# processed: M0072_03_53061_iPhone_iphone6.npy(frames num: 363)
# processed: M0078_01_61579_iPhone_6s.npy(frames num: 311)
# processed: F0182_03_79428_iPhone_iphone6.npy(frames num: 350)
# processed: M0082_03_62045_iPhone_iphone6.npy(frames num: 377)
# processed: F0051_02_4910725836_Android_htc.npy(frames num: 557)
# processed: F0200_03_90741_Android_htc.npy(frames num: 386)
# processed: M0076_03_14590_Android_htc.npy(frames num: 240)

# %%
predictions_path
# Out:
# './3_predictions/pca_W_mfcc/'

# %% [markdown]
# <b>Задание 2.</b> Проверить качество распознавания (WER) на полученных predictions

# %% [markdown]
# <b>Задание 3.</b> Попробовать улучшить результаты распознавания за счет:
# - изменения архитектуры DNN
# - изменения набора входных признаков
# - изменения типа нормализации (не только по среднему, но и по дисперсии)
