# %% [markdown]
# # Урок 5
#
# В этом уроке мы будем расвознавать файлы, содержащие не одну, а уже последовательности цифр. Также мы усложним акустическую модель – будем использовать предварительно обученный нейросетевой классификатор. Для удобства возьмем уже полученные предсказания для кадров всех используемых записей.
#
# Для того, чтобы иметь возможность декодировать последовательности слов, нужно добавить в финальные узлы графа переходы в нулевой узел, из которого токены заново могу идти по ветвям.
#
# <img src="graph_5.jpg">
#
# <b>Задание 1:</b> Добавить возможность перехода в нулевой узел для последних узлов в каждой ветви графа. Словарь с эталонами хранится в файле lexicon.

# %%
import GraphMaker
import AcoModels
import FtrFile
import wer
import numpy as np
import os


class State:
    def __init__(self, model, idx):
        self.model = model
        self.word = None
        self.isFinal = False
        self.nextStates = []
        self.idx = idx
        self.bestToken = None
        
#---------------------------------TODO--------------------------------------        
def DictReader(dictName):
    with open(dictName, 'rt') as dict_file:
        for line in dict_file:
            line = line.strip()
            if not line:
                continue
            parts = line.split()
            word = parts[0]
            phonemes = parts[1:]
            yield word, phonemes
#---------------------------------------------------------------------------

def load_graph(rxfilename, AMs):
    startState = State(None, 0)
    graph = [startState, ]
    stateIdx = 1
    #-----------------------------------------TODO--------------------------
    for word, phones in DictReader(rxfilename):
        prevState = startState
        for frame in range(len(phones)):
            phoneme_model = AMs.findModelbyName(phones[frame])
            state = State(phoneme_model, stateIdx)
            state.currentWord = word
            state.nextStates.append(state)  # add loop
            prevState.nextStates.append(state)
            prevState = state  # prevState is state = true
            graph.append(state)
            stateIdx += 1
        if state:
            state.word = word
            state.isFinal = True
            state.nextStates.append(startState)
    #-----------------------------------------------------------------------
    return graph

# %% [markdown]
# Но необходимо сразу же ввести шраф за выход из слова – wd_add.Дело в том,что длинное слово вероятнее собрать из нескольких коротких, если таковые есть – поскольку у этих коротких слов может оказаться лучшая дистанция относительно полного слова . Например, слово «надо» удобно составить из «на до», или «на да», или «но да», или «над э», или «над а» – что лучше подходит к
# звуку, то и выбирай.
#
# Чтобы это обуздать, заводят штраф wd_add. Этот штраф мы прибавляем к «дистанции» токена каждый раз, когда встречаем идентификатор слова. Его подбирают на какой-то базе так,чтобы качество было максимальным.
#
# Для этого надо реализовать функцию virtualNodePass, которая будет штрафовать наши токены за выход из слова и повторное прохождение через нулевой узел.
#
# Чтобы оценить результаты нашего декодирования мы будем использовать уже готовую утилиту wer.py для вычисления WER в функции computeWER.

# %%
class Token:
    def __init__(self, state, dist=0.0, sentence=""):
        self.state = state
        self.dist = dist
        self.sentence = sentence
        self.alive = True
        

def findBest(Tokens):
    minDist = None
    bestToken = 0
    for i in range(len(Tokens)):
        if Tokens[i].alive == True:
            if minDist == None:
                minDist = Tokens[i].dist
                bestToken = Tokens[i]
            elif Tokens[i].dist <= minDist:
                minDist = Tokens[i].dist
                bestToken = Tokens[i]
    return bestToken


def beamPrunning(nextTokens, thr_common):
    bestToken = findBest(nextTokens)
    bestDist = bestToken.dist
    for i in range(len(nextTokens)):
        if nextTokens[i].alive == True and nextTokens[i].dist >= bestDist + thr_common:
            nextTokens[i].alive = False
    return nextTokens, bestDist


def statePrunning(nextTokens):
    for i in range(len(nextTokens)):
        state_index = nextTokens[i].state.idx
        if graph[state_index].bestToken == None:
            graph[state_index].bestToken = nextTokens[i]
        else:
            if nextTokens[i].dist <= graph[state_index].bestToken.dist:
                graph[state_index].bestToken.alive = False
                graph[state_index].bestToken = nextTokens[i]
            else:
                nextTokens[i].alive = False
    return nextTokens


def virtualNodePass(token, newToken):
    #---------------------TODO-----------------------
    newToken.dist += wd_add
    #------------------------------------------------
    # разделение слов в высказывании знаком '-':
    if newToken.sentence and token.state.word != '<sil>':
        newToken.sentence += '-'
    # добавление нового слова в высказывание:
    if token.state.word != '<sil>':
        newToken.sentence += token.state.word
    return newToken


def decoding(filename, num_file, AMs, graph, path2predict, thr_common, wd_add):

    print("num_file: {}, file_name: {}".format(num_file, filename))
    startState = graph[0]
    activeTokens = [Token(startState), ]
    nextTokens = []
    AMs.loadPrediction('{}/{}.npy'.format(path2predict, filename))

    for frame in range(len(AMs.predicts)):
        runningBestDist = 0
        for token in activeTokens:
            if token.alive:
                for transitState in token.state.nextStates:
                    newToken = Token(transitState, token.dist, token.sentence)
                    # virtual node pass and penalty for word:
                    #----------------TODO------------------------------------
                    if newToken.state.idx == 0:
                        newToken = virtualNodePass(token, newToken)
                        activeTokens.append(newToken)
                        continue
                    #--------------------------------------------------------
                    # end virtual node pass ...
                    newToken.dist += AMs.getDist(transitState.model, frame)
                    nextTokens.append(newToken)
        #make pruning:
        nextTokens = statePrunning(nextTokens)
        nextTokens, bestDist = beamPrunning(nextTokens, thr_common)

        activeTokens = nextTokens
        for token in nextTokens:
            index = token.state.idx
            if graph[index].bestToken:
                graph[index].bestToken = None
        nextTokens = []

    # finding final Tokens
    finalTokens = []
    for token in activeTokens:
        if token.state.isFinal and token.alive:
            finalTokens.append(token)

    assert len(finalTokens) != 0
    winToken = findBest(finalTokens)
    fn.write(str(filename) + ' ' + winToken.sentence.replace('-', ' ') + '\n')

    return frame


def computeWer(testName, resName):
    
    WER = wer.computeWER(testName, resName)
    print('\n' + '-'*10 + 'RESULT OF RECOGNITION:' + '--'*10 + '\n')
    print('%WER is {}'.format(WER))

# %% [markdown]
# Запустим нашу программу.

# %%
import time

lexicon = 'lexicon'                   # словарь для цифр с фонемной транскрипцией
phones_dict = 'phones'                # набор используемых фонем
test_mfcc = 'ark,t:test_mfcc.txtftr' # признаки записей 
path2predict = 'binaryPredict'        # папка с предсказаниями
resName = 'decode_results'            # файл с результатами декодирования
testName = 'test_ref.txt'             # файл с текстом записей

thr_common = 60
wd_add = 55 
s_time = time.time()

# 1. Make acoustic model:
AMs = AcoModels.AcoModelSet(phones_dict)
AMs.loadPosteriors('posteriors.npy')

# 2. Load and check graph from lexicon:
graph = GraphMaker.load_graph(lexicon, AMs)
GraphMaker.check_graph(graph)

#3. Load filename from test_reference:
test_list = []
with open(testName, 'r') as fn:
    for line in fn:
        test_list.append(line.split()[0])

#4. Decoding:
print("\nDECODING IS STARTED...")
num_file = 0
numbFrame = 0
with open(resName, 'w') as fn:
    for filename in test_list:
        if num_file < 1000:
            decoding(filename, num_file, AMs, graph, path2predict, thr_common, wd_add)                         
            num_file += 1
            numbFrame += len(AMs.predicts)
        else: break

#4. Compute WER:
computeWer(testName, resName)

#5. Print time and RTF:
time = time.time() - s_time
minut = int(time / 60)
second = time - minut * 60
print("\nTOTAL TIME: {} min {} sec".format(minut, round(second, 2)))
rtf = time / (numbFrame * 0.01)
print("RTF: {}".format(round(rtf, 3)))
# Out:
# DECODING IS STARTED...
# num_file: 0, file_name: M0089_02_0273618495_Android_nexus
# num_file: 1, file_name: M0072_02_05469_Android_nexus
# num_file: 2, file_name: M0045_01_8453679021_iPhone_Iphone5
# num_file: 3, file_name: F0197_03_2738015469_iPhone_iphone6
# num_file: 4, file_name: F0031_02_04279_iPhone_iphone6
# num_file: 5, file_name: F0199_03_6482310759_Android_nexus
# num_file: 6, file_name: F0031_03_17806_iPhone_6s
# num_file: 7, file_name: M0036_03_09687_Android_SM
# num_file: 8, file_name: F0010_02_1392408567_iPhone_iphone6
# num_file: 9, file_name: M0070_03_26738_Android_htc
# num_file: 10, file_name: F0010_02_89071_iPhone_iphone6
# num_file: 11, file_name: F0042_03_1832965470_Android_SM_Gal_J3
# num_file: 12, file_name: M0047_03_72690_Android_nexus
# num_file: 13, file_name: F0034_01_70531_iPhone_Iphone5
# num_file: 14, file_name: M0062_01_70531_iPhone_6s
# num_file: 15, file_name: M0088_01_97842_Android_SM
# num_file: 16, file_name: M0064_03_6382074195_iPhone_iphone6
# num_file: 17, file_name: M0038_02_5037649281_Android_htc
# num_file: 18, file_name: F0152_01_20914_Android_SM
# num_file: 19, file_name: F0199_02_1392408567_iPhone_iphone6
# num_file: 20, file_name: F0009_03_52934_Android_SM
# num_file: 21, file_name: M0033_03_9263475180_Android_nexus
# num_file: 22, file_name: F0051_02_29640_Android_htc
# num_file: 23, file_name: F0154_03_53970_Android_SM_Gal_J3
# num_file: 24, file_name: M0002_02_89071_iPhone_iphone6
# num_file: 25, file_name: F0051_03_86071_Android_nexus
# num_file: 26, file_name: F0034_02_42365_iPhone_iphone6
# num_file: 27, file_name: M0049_01_43028_Android_htc
# num_file: 28, file_name: M0012_03_9203745681_Android_nexus
# num_file: 29, file_name: M0070_02_03271_Android_nexus
# num_file: 30, file_name: F0034_02_1392408567_iPhone_iphone6
# num_file: 31, file_name: M0057_03_60475_iPhone_6s
# num_file: 32, file_name: M0038_02_04279_iPhone_iphone6
# num_file: 33, file_name: F0199_01_7546301298_Android_nexus
# num_file: 34, file_name: M0057_02_57490_Android_SM_Gal_J3
# num_file: 35, file_name: M0001_03_89462_Android_nexus
# num_file: 36, file_name: M0026_02_0256481739_iPhone_6s
# num_file: 37, file_name: M0077_02_0273618495_Android_nexus
# num_file: 38, file_name: F0173_01_29351_iPhone_6s
# num_file: 39, file_name: F0191_03_38964_Android_htc
# num_file: 40, file_name: M0046_02_2174905683_Android_htc
# num_file: 41, file_name: F0009_02_89071_iPhone_iphone6
# num_file: 42, file_name: F0052_01_2637015489_iPhone_6s
# num_file: 43, file_name: F0201_02_75896_Android_htc
# num_file: 44, file_name: M0016_02_63148_iPhone_Iphone5
# num_file: 45, file_name: F0073_01_23985_iPhone_6s
# num_file: 46, file_name: F0200_02_2514860973_iPhone_6s
# num_file: 47, file_name: M0006_03_59012_Android_SM_Gal_J3
# num_file: 48, file_name: M0089_01_65718_iPhone_6s
# num_file: 49, file_name: F0035_03_14682_Android_SM_Gal_J3
# num_file: 50, file_name: F0199_01_1690483752_Android_SM_Gal_J3
# num_file: 51, file_name: F0050_03_18924_Android_SM
# num_file: 52, file_name: F0182_03_07516_Android_htc
# num_file: 53, file_name: M0065_03_6382074195_iPhone_iphone6
# num_file: 54, file_name: F0173_01_02675_Android_SM
# num_file: 55, file_name: F0117_01_75362_Android_SM
# num_file: 56, file_name: M0002_03_5602743918_Android_SM_Gal_J3
# num_file: 57, file_name: F0119_02_51762_Android_SM_Gal_J3
# num_file: 58, file_name: F0020_03_0896425173_Android_SM
# num_file: 59, file_name: M0048_02_17538_Android_htc
# num_file: 60, file_name: M0082_01_2360481975_iPhone_6s
# num_file: 61, file_name: F0032_02_1894372056_iPhone_iphone6
# num_file: 62, file_name: F0172_01_85346_Android_SM
# num_file: 63, file_name: F0168_01_87046_iPhone_6s
# num_file: 64, file_name: F0152_01_27864_iPhone_6s
# num_file: 65, file_name: F0157_01_3407869152_iPhone_6s
# num_file: 66, file_name: F0199_03_10359_Android_nexus
# num_file: 67, file_name: M0041_01_4615028739_iPhone_Iphone5
# num_file: 68, file_name: F0199_02_04279_iPhone_iphone6
# num_file: 69, file_name: F0029_02_59021_Android_htc
# num_file: 70, file_name: M0001_01_54398_iPhone_6s
# num_file: 71, file_name: M0013_02_51386_iPhone_iphone6
# num_file: 72, file_name: F0117_01_32074_Android_SM
# num_file: 73, file_name: M0004_01_9761823504_iPhone_6s
# num_file: 74, file_name: F0119_01_92374_iPhone_6s
# num_file: 75, file_name: F0029_03_14358_Android_SM
# num_file: 76, file_name: F0197_03_83971_iPhone_iphone6
# num_file: 77, file_name: M0071_03_7516290438_Android_htc
# num_file: 78, file_name: F0020_02_74681_Android_htc
# num_file: 79, file_name: F0027_01_2637015489_iPhone_6s
# num_file: 80, file_name: M0053_03_60381_iPhone_6s
# num_file: 81, file_name: M0006_02_9730581624_Android_htc
# num_file: 82, file_name: F0022_02_1763092458_iPhone_Iphone5
# num_file: 83, file_name: F0181_02_94863_Android_nexus
# num_file: 84, file_name: F0032_02_4029763518_iPhone_iphone6
# num_file: 85, file_name: M0058_02_42365_iPhone_iphone6
# num_file: 86, file_name: F0021_03_91605_iPhone_6s
# num_file: 87, file_name: F0061_03_9435680172_Android_htc
# num_file: 88, file_name: M0074_02_1745983062_iPhone_6s
# num_file: 89, file_name: M0071_03_38964_Android_htc
# num_file: 90, file_name: M0059_01_48150_iPhone_6s
# num_file: 91, file_name: M0047_02_6347058219_iPhone_6s
# num_file: 92, file_name: F0199_03_76541_Android_SM_Gal_J3
# num_file: 93, file_name: F0200_01_31049_Android_nexus
# num_file: 94, file_name: F0154_02_1894372056_iPhone_iphone6
# num_file: 95, file_name: F0029_03_1230694587_Android_SM
# num_file: 96, file_name: F0197_02_81026_iPhone_6s
# num_file: 97, file_name: M0036_03_3927810546_Android_SM
# num_file: 98, file_name: M0049_02_2691345807_Android_htc
# num_file: 99, file_name: M0065_02_97063_Android_nexus
# num_file: 100, file_name: M0057_02_4731085629_Android_SM_Gal_J3
# num_file: 101, file_name: M0077_02_53107_Android_nexus
# num_file: 102, file_name: F0035_02_42365_iPhone_iphone6
# num_file: 103, file_name: F0199_03_0856371492_Android_nexus
# num_file: 104, file_name: M0054_02_4029763518_iPhone_iphone6
# num_file: 105, file_name: M0013_02_4029763518_iPhone_iphone6
# num_file: 106, file_name: M0039_01_4762598103_Android_htc
# num_file: 107, file_name: M0076_03_8726039514_Android_htc
# num_file: 108, file_name: F0175_01_49608_iPhone_6s
# num_file: 109, file_name: F0157_01_0738652941_Android_SM
# num_file: 110, file_name: M0006_02_89071_iPhone_iphone6
# num_file: 111, file_name: F0191_01_43705_iPhone_6s
# num_file: 112, file_name: M0048_02_4067593812_Android_htc
# num_file: 113, file_name: M0059_02_42365_iPhone_iphone6
# num_file: 114, file_name: M0067_01_9872615403_iPhone_6s
# num_file: 115, file_name: F0117_02_03924_Android_htc
# num_file: 116, file_name: M0044_02_42365_iPhone_iphone6
# num_file: 117, file_name: F0068_01_98264_iPhone_6s
# num_file: 118, file_name: M0044_02_51386_iPhone_iphone6
# num_file: 119, file_name: F0050_02_1392408567_iPhone_iphone6
# num_file: 120, file_name: F0169_01_14389_Android_SM
# num_file: 121, file_name: M0038_03_36954_iPhone_6s
# num_file: 122, file_name: F0199_01_26094_Android_nexus
# num_file: 123, file_name: M0078_02_25783_Android_nexus
# num_file: 124, file_name: M0089_01_7458109632_Android_SM
# num_file: 125, file_name: M0053_02_0926754831_Android_SM
# num_file: 126, file_name: M0060_03_79428_iPhone_iphone6
# num_file: 127, file_name: F0021_02_89071_iPhone_iphone6
# num_file: 128, file_name: F0068_02_74096_Android_SM_Gal_J3
# num_file: 129, file_name: M0088_02_60487_Android_nexus
# num_file: 130, file_name: M0037_03_54782_Android_nexus
# num_file: 131, file_name: M0013_02_16073_Android_htc
# num_file: 132, file_name: F0015_03_74126_Android_nexus
# num_file: 133, file_name: M0046_02_29845_Android_htc
# num_file: 134, file_name: M0082_03_9075642813_Android_htc
# num_file: 135, file_name: F0022_03_85310_Android_SM
# num_file: 136, file_name: F0011_02_42365_iPhone_iphone6
# num_file: 137, file_name: M0056_02_51386_iPhone_iphone6
# num_file: 138, file_name: F0154_03_3142985706_Android_nexus
# num_file: 139, file_name: M0046_03_73890_Android_SM
# num_file: 140, file_name: F0090_02_26835_Android_nexus
# num_file: 141, file_name: M0072_02_15238_Android_SM_Gal_J3
# num_file: 142, file_name: M0045_01_29673_Android_htc
# num_file: 143, file_name: F0173_01_4923510687_Android_SM
# num_file: 144, file_name: F0119_03_30275_Android_SM
# num_file: 145, file_name: M0037_02_90864_Android_htc
# num_file: 146, file_name: F0201_02_4950631278_Android_htc
# num_file: 147, file_name: M0072_01_2765304981_iPhone_6s
# num_file: 148, file_name: F0154_01_27864_iPhone_6s
# num_file: 149, file_name: F0090_02_21409_Android_nexus
# num_file: 150, file_name: M0071_02_49586_Android_nexus
# num_file: 151, file_name: M0001_03_4697803125_Android_SM_Gal_J3
# num_file: 152, file_name: F0029_02_74681_Android_htc
# num_file: 153, file_name: M0055_02_4029763518_iPhone_iphone6
# num_file: 154, file_name: F0191_02_82673_Android_SM_Gal_J3
# num_file: 155, file_name: M0033_03_14769_Android_SM_Gal_J3
# num_file: 156, file_name: M0037_02_6780524931_Android_htc
# num_file: 157, file_name: F0073_03_79428_iPhone_iphone6
# num_file: 158, file_name: F0020_03_85310_Android_SM
# num_file: 159, file_name: F0191_03_7516290438_Android_htc
# num_file: 160, file_name: F0200_03_58914_Android_htc
# num_file: 161, file_name: M0006_01_9761823504_iPhone_6s
# num_file: 162, file_name: F0034_02_89071_iPhone_iphone6
# num_file: 163, file_name: M0001_01_70216_iPhone_6s
# num_file: 164, file_name: M0037_01_0594267381_Android_htc
# num_file: 165, file_name: M0045_01_4682107593_iPhone_Iphone5
# num_file: 166, file_name: M0058_03_14682_Android_SM_Gal_J3
# num_file: 167, file_name: F0169_02_4029763518_iPhone_iphone6
# num_file: 168, file_name: M0055_02_9730581624_Android_htc
# num_file: 169, file_name: F0027_03_2107835946_iPhone_6s
# num_file: 170, file_name: F0005_02_29640_Android_htc
# num_file: 171, file_name: F0022_03_91605_iPhone_6s
# num_file: 172, file_name: F0181_02_25961_Android_SM_Gal_J3
# num_file: 173, file_name: F0051_01_87901_iPhone_6s
# num_file: 174, file_name: M0089_03_53061_iPhone_iphone6
# num_file: 175, file_name: M0006_03_05849_Android_SM_Gal_J3
# num_file: 176, file_name: M0046_01_9307426185_iPhone_Iphone5
# num_file: 177, file_name: M0016_02_6714258309_Android_htc
# num_file: 178, file_name: F0191_01_97846_Android_SM
# num_file: 179, file_name: M0030_03_73284_iPhone_6s
# num_file: 180, file_name: F0009_03_29136_iPhone_6s
# num_file: 181, file_name: M0072_03_89265_Android_htc
# num_file: 182, file_name: F0182_02_20759_Android_nexus
# num_file: 183, file_name: M0002_03_04238_Android_SM_Gal_J3
# num_file: 184, file_name: F0011_01_54398_iPhone_6s
# num_file: 185, file_name: M0043_02_5213840967_Android_htc
# num_file: 186, file_name: M0064_03_13740_Android_htc
# num_file: 187, file_name: M0001_03_5897106423_Android_SM_Gal_J3
# num_file: 188, file_name: M0006_02_42365_iPhone_iphone6
# num_file: 189, file_name: M0075_02_16094_Android_nexus
# num_file: 190, file_name: M0030_02_95230_Android_htc
# num_file: 191, file_name: M0082_02_83172_Android_nexus
# num_file: 192, file_name: F0157_01_0435891276_iPhone_6s
# num_file: 193, file_name: M0065_03_02764_Android_htc
# num_file: 194, file_name: M0065_01_2593068741_iPhone_6s
# num_file: 195, file_name: M0057_01_23679_iPhone_6s
# num_file: 196, file_name: M0016_01_48150_iPhone_6s
# num_file: 197, file_name: F0069_02_50782_Android_nexus
# num_file: 198, file_name: M0033_03_42950_Android_nexus
# num_file: 199, file_name: F0152_01_0738652941_Android_SM
# num_file: 200, file_name: M0065_01_9872615403_iPhone_6s
# num_file: 201, file_name: F0199_03_98320_Android_SM_Gal_J3
# num_file: 202, file_name: M0039_03_16074_Android_SM_Gal_J3
# num_file: 203, file_name: F0182_03_53061_iPhone_iphone6
# num_file: 204, file_name: M0078_02_4258637190_Android_SM_Gal_J3
# num_file: 205, file_name: M0076_03_14590_Android_htc
# num_file: 206, file_name: M0071_03_53061_iPhone_iphone6
# num_file: 207, file_name: F0095_03_6382074195_iPhone_iphone6
# num_file: 208, file_name: F0175_01_35721_iPhone_6s
# num_file: 209, file_name: F0117_02_0578342619_Android_htc
# num_file: 210, file_name: M0048_01_82310_iPhone_Iphone5
# num_file: 211, file_name: F0005_03_59012_Android_SM_Gal_J3
# num_file: 212, file_name: F0031_02_51386_iPhone_iphone6
# num_file: 213, file_name: F0090_03_93501_Android_SM
# num_file: 214, file_name: M0006_03_5897106423_Android_SM_Gal_J3
# num_file: 215, file_name: F0168_01_4290583176_Android_SM
# num_file: 216, file_name: F0021_02_04279_iPhone_iphone6
# num_file: 217, file_name: M0016_03_0896425173_Android_SM
# num_file: 218, file_name: F0020_01_2637015489_iPhone_6s
# num_file: 219, file_name: M0082_01_89524_iPhone_6s
# num_file: 220, file_name: M0067_02_7963108245_Android_nexus
# num_file: 221, file_name: F0042_01_62795_iPhone_Iphone5
# num_file: 222, file_name: M0089_01_24309_iPhone_6s
# num_file: 223, file_name: M0038_03_5910367284_iPhone_6s
# num_file: 224, file_name: M0065_03_9308247615_Android_htc
# num_file: 225, file_name: F0095_02_1652897340_Android_nexus
# num_file: 226, file_name: F0052_01_87901_iPhone_6s
# num_file: 227, file_name: F0021_01_5326071948_iPhone_6s
# num_file: 228, file_name: M0067_02_37528_Android_SM_Gal_J3
# num_file: 229, file_name: M0053_02_79645_Android_SM
# num_file: 230, file_name: M0038_01_75963_Android_htc
# num_file: 231, file_name: M0049_02_0578342619_Android_htc
# num_file: 232, file_name: F0182_03_2738015469_iPhone_iphone6
# num_file: 233, file_name: M0076_03_89265_Android_htc
# num_file: 234, file_name: F0154_01_54109_iPhone_6s
# num_file: 235, file_name: F0029_02_51386_iPhone_iphone6
# num_file: 236, file_name: M0001_03_59012_Android_SM_Gal_J3
# num_file: 237, file_name: M0047_01_56947_iPhone_Iphone5
# num_file: 238, file_name: M0070_03_83971_iPhone_iphone6
# num_file: 239, file_name: F0032_02_46783_Android_htc
# num_file: 240, file_name: M0072_01_6527480931_iPhone_6s
# num_file: 241, file_name: F0200_01_7546301298_Android_nexus
# num_file: 242, file_name: M0049_03_23654_Android_SM_Gal_J3
# num_file: 243, file_name: F0201_03_10359_Android_nexus
# num_file: 244, file_name: M0001_03_8795106423_Android_nexus
# num_file: 245, file_name: M0067_03_83971_iPhone_iphone6
# num_file: 246, file_name: F0169_03_9437586120_Android_nexus
# num_file: 247, file_name: F0182_01_85213_iPhone_6s
# num_file: 248, file_name: F0169_01_4290583176_Android_SM
# num_file: 249, file_name: F0119_03_2509134786_iPhone_6s
# num_file: 250, file_name: M0016_03_0931472685_Android_SM
# num_file: 251, file_name: F0020_02_1253068479_Android_htc
# num_file: 252, file_name: F0119_03_8631509472_Android_SM
# num_file: 253, file_name: F0152_03_35891_iPhone_6s
# num_file: 254, file_name: M0062_03_02764_Android_htc
# num_file: 255, file_name: F0050_02_1894372056_iPhone_iphone6
# num_file: 256, file_name: F0117_02_17658_Android_htc
# num_file: 257, file_name: M0028_03_5602743918_Android_SM_Gal_J3
# num_file: 258, file_name: M0058_01_43652_iPhone_6s
# num_file: 259, file_name: F0034_02_1894372056_iPhone_iphone6
# num_file: 260, file_name: M0013_01_9761823504_iPhone_6s
# num_file: 261, file_name: M0056_03_2594680137_iPhone_6s
# num_file: 262, file_name: M0072_03_14590_Android_htc
# num_file: 263, file_name: F0020_02_5213840967_Android_htc
# num_file: 264, file_name: F0168_01_35721_iPhone_6s
# num_file: 265, file_name: M0013_01_4351796082_iPhone_6s
# num_file: 266, file_name: M0077_02_49738_Android_nexus
# num_file: 267, file_name: F0011_03_8795106423_Android_nexus
# num_file: 268, file_name: F0009_03_31560_iPhone_6s
# num_file: 269, file_name: F0172_03_18572_Android_nexus
# num_file: 270, file_name: M0056_02_4910725836_Android_htc
# num_file: 271, file_name: F0182_01_59146_Android_SM
# num_file: 272, file_name: M0081_02_05469_Android_nexus
# num_file: 273, file_name: F0169_03_9210357846_Android_SM_Gal_J3
# num_file: 274, file_name: M0002_02_89254_Android_htc
# num_file: 275, file_name: M0006_01_4351796082_iPhone_6s
# num_file: 276, file_name: F0154_01_76853_Android_SM
# num_file: 277, file_name: F0034_03_9263475180_Android_nexus
# num_file: 278, file_name: F0130_03_8631509472_Android_SM
# num_file: 279, file_name: F0175_03_60475_iPhone_6s
# num_file: 280, file_name: M0057_01_87901_iPhone_6s
# num_file: 281, file_name: M0007_02_07429_Android_nexus
# num_file: 282, file_name: M0037_01_51902_iPhone_Iphone5
# num_file: 283, file_name: M0058_02_16073_Android_htc
# num_file: 284, file_name: M0046_02_6780524931_Android_htc
# num_file: 285, file_name: M0049_01_69175_Android_htc
# num_file: 286, file_name: M0067_03_51983_Android_htc
# num_file: 287, file_name: F0027_03_91605_iPhone_6s
# num_file: 288, file_name: F0009_02_51386_iPhone_iphone6
# num_file: 289, file_name: M0038_01_9375620841_iPhone_Iphone5
# num_file: 290, file_name: F0199_01_27413_Android_SM_Gal_J3
# num_file: 291, file_name: M0004_02_51386_iPhone_iphone6
# num_file: 292, file_name: M0071_03_2738015469_iPhone_iphone6
# num_file: 293, file_name: F0069_03_6382074195_iPhone_iphone6
# num_file: 294, file_name: F0191_02_0938157624_Android_SM_Gal_J3
# num_file: 295, file_name: M0002_01_1324670895_iPhone_6s
# num_file: 296, file_name: F0015_03_5873419602_Android_nexus
# num_file: 297, file_name: M0081_03_78053_Android_htc
# num_file: 298, file_name: F0069_03_62045_iPhone_iphone6
# num_file: 299, file_name: M0053_03_5607924138_Android_SM
# num_file: 300, file_name: M0074_03_1247093658_Android_SM
# num_file: 301, file_name: F0201_01_6931875420_Android_SM
# num_file: 302, file_name: M0064_03_89265_Android_htc
# num_file: 303, file_name: F0042_02_4910725836_Android_htc
# num_file: 304, file_name: F0061_02_7963108245_Android_nexus
# num_file: 305, file_name: M0030_03_1429067358_iPhone_6s
# num_file: 306, file_name: F0068_01_70531_iPhone_6s
# num_file: 307, file_name: M0058_03_2687041593_Android_SM_Gal_J3
# num_file: 308, file_name: M0044_01_4802765319_Android_htc
# num_file: 309, file_name: M0054_03_9203745681_Android_nexus
# num_file: 310, file_name: M0081_02_74096_Android_SM_Gal_J3
# num_file: 311, file_name: F0201_02_51386_iPhone_iphone6
# num_file: 312, file_name: F0119_02_43765_Android_nexus
# num_file: 313, file_name: M0079_02_3017568429_Android_nexus
# num_file: 314, file_name: M0071_01_23985_iPhone_6s
# num_file: 315, file_name: F0061_02_03271_Android_nexus
# num_file: 316, file_name: F0011_02_51386_iPhone_iphone6
# num_file: 317, file_name: F0182_03_83971_iPhone_iphone6
# num_file: 318, file_name: F0182_01_8167295430_iPhone_6s
# num_file: 319, file_name: F0181_01_92703_iPhone_6s
# num_file: 320, file_name: F0021_03_5267981034_iPhone_6s
# num_file: 321, file_name: M0079_03_31248_iPhone_6s
# num_file: 322, file_name: M0072_03_13740_Android_htc
# num_file: 323, file_name: M0041_03_53067_Android_SM
# num_file: 324, file_name: F0011_01_70216_iPhone_6s
# num_file: 325, file_name: F0005_02_17538_Android_htc
# num_file: 326, file_name: F0157_01_93602_Android_SM
# num_file: 327, file_name: M0088_02_5621079348_Android_nexus
# num_file: 328, file_name: M0030_03_85310_Android_SM
# num_file: 329, file_name: F0197_03_7629538140_Android_htc
# num_file: 330, file_name: F0200_01_3621475890_Android_nexus
# num_file: 331, file_name: F0157_03_2738015469_iPhone_iphone6
# num_file: 332, file_name: F0052_03_32198_iPhone_6s
# num_file: 333, file_name: M0001_03_70315_Android_nexus
# num_file: 334, file_name: M0057_02_90587_Android_SM_Gal_J3
# num_file: 335, file_name: F0068_02_5692438017_Android_SM_Gal_J3
# num_file: 336, file_name: F0068_02_8643201957_Android_nexus
# num_file: 337, file_name: M0016_01_5326071948_iPhone_6s
# num_file: 338, file_name: F0050_01_24789_Android_SM
# num_file: 339, file_name: F0005_03_5734802691_Android_nexus
# num_file: 340, file_name: M0002_03_71638_Android_nexus
# num_file: 341, file_name: M0016_03_1429067358_iPhone_6s
# num_file: 342, file_name: F0157_03_82493_Android_htc
# num_file: 343, file_name: M0053_02_2608457193_Android_SM
# num_file: 344, file_name: F0182_02_68143_Android_nexus
# num_file: 345, file_name: M0082_03_08153_Android_htc
# num_file: 346, file_name: M0057_01_8102574936_iPhone_6s
# num_file: 347, file_name: F0031_03_5609217384_iPhone_6s
# num_file: 348, file_name: F0027_03_73890_Android_SM
# num_file: 349, file_name: M0030_01_4523869701_iPhone_Iphone5
# num_file: 350, file_name: F0157_01_76853_Android_SM
# num_file: 351, file_name: M0037_02_51386_iPhone_iphone6
# num_file: 352, file_name: M0006_03_4697803125_Android_SM_Gal_J3
# num_file: 353, file_name: F0181_02_20759_Android_nexus
# num_file: 354, file_name: M0030_03_12948_iPhone_6s
# num_file: 355, file_name: F0068_01_4523869701_iPhone_6s
# num_file: 356, file_name: M0007_02_7639814520_Android_nexus
# num_file: 357, file_name: M0081_03_60189_Android_htc
# num_file: 358, file_name: F0199_01_37851_Android_nexus
# num_file: 359, file_name: M0001_02_36841_iPhone_6s
# num_file: 360, file_name: M0056_02_29640_Android_htc
# num_file: 361, file_name: M0044_02_1253068479_Android_htc
# num_file: 362, file_name: F0119_01_98014_Android_SM
# num_file: 363, file_name: M0049_03_53970_Android_SM_Gal_J3
# num_file: 364, file_name: F0172_01_02675_Android_SM
# num_file: 365, file_name: M0033_02_1392408567_iPhone_iphone6
# num_file: 366, file_name: F0020_02_04279_iPhone_iphone6
# num_file: 367, file_name: M0071_02_83172_Android_nexus
# num_file: 368, file_name: F0069_02_3017568429_Android_nexus
# num_file: 369, file_name: M0045_03_41235_Android_SM
# num_file: 370, file_name: F0032_03_85792_iPhone_6s
# num_file: 371, file_name: F0154_02_42365_iPhone_iphone6
# num_file: 372, file_name: F0020_03_2107835946_iPhone_6s
# num_file: 373, file_name: F0154_01_7412980653_Android_SM
# num_file: 374, file_name: F0021_02_16073_Android_htc
# num_file: 375, file_name: M0060_01_8102574936_iPhone_6s
# num_file: 376, file_name: M0075_01_23985_iPhone_6s
# num_file: 377, file_name: F0119_01_6519347208_iPhone_6s
# num_file: 378, file_name: F0172_01_14389_Android_SM
# num_file: 379, file_name: M0053_02_5397410268_iPhone_6s
# num_file: 380, file_name: M0089_02_9320678415_Android_nexus
# num_file: 381, file_name: M0065_03_53061_iPhone_iphone6
# num_file: 382, file_name: M0026_01_87901_iPhone_6s
# num_file: 383, file_name: M0026_03_3978520416_iPhone_6s
# num_file: 384, file_name: F0152_01_54109_iPhone_6s
# num_file: 385, file_name: F0022_03_2107835946_iPhone_6s
# num_file: 386, file_name: M0044_02_5213840967_Android_htc
# num_file: 387, file_name: M0089_02_8295164703_Android_nexus
# num_file: 388, file_name: M0041_03_5487910236_Android_SM
# num_file: 389, file_name: M0039_02_1894372056_iPhone_iphone6
# num_file: 390, file_name: F0010_01_63470_iPhone_6s
# num_file: 391, file_name: F0200_03_53061_iPhone_iphone6
# num_file: 392, file_name: M0001_02_4987305216_Android_SM
# num_file: 393, file_name: M0053_03_80426_Android_SM
# num_file: 394, file_name: M0072_02_03271_Android_nexus
# num_file: 395, file_name: F0031_02_1392408567_iPhone_iphone6
# num_file: 396, file_name: M0059_01_23679_iPhone_6s
# num_file: 397, file_name: M0026_02_1306459728_Android_SM
# num_file: 398, file_name: F0197_03_38964_Android_htc
# num_file: 399, file_name: M0007_02_58307_Android_SM_Gal_J3
# num_file: 400, file_name: M0045_01_28961_Android_htc
# num_file: 401, file_name: F0011_02_9730581624_Android_htc
# num_file: 402, file_name: M0058_01_2637015489_iPhone_6s
# num_file: 403, file_name: F0011_02_1392408567_iPhone_iphone6
# num_file: 404, file_name: F0005_03_39685_Android_nexus
# num_file: 405, file_name: M0065_03_51983_Android_htc
# num_file: 406, file_name: M0033_03_74126_Android_nexus
# num_file: 407, file_name: M0059_02_17538_Android_htc
# num_file: 408, file_name: M0028_02_29507_iPhone_Iphone5
# num_file: 409, file_name: M0044_01_69047_iPhone_Iphone5
# num_file: 410, file_name: F0154_03_2870546319_Android_SM_Gal_J3
# num_file: 411, file_name: M0082_03_4532091867_iPhone_iphone6
# num_file: 412, file_name: M0004_03_84312_Android_SM_Gal_J3
# num_file: 413, file_name: M0081_02_8719463205_Android_SM_Gal_J3
# num_file: 414, file_name: M0036_02_4029763518_iPhone_iphone6
# num_file: 415, file_name: M0055_02_1392408567_iPhone_iphone6
# num_file: 416, file_name: M0057_01_43652_iPhone_6s
# num_file: 417, file_name: F0130_01_43186_Android_SM
# num_file: 418, file_name: M0037_03_9015826743_Android_SM_Gal_J3
# num_file: 419, file_name: M0001_02_80316_Android_SM
# num_file: 420, file_name: M0081_03_5139276408_Android_htc
# num_file: 421, file_name: F0022_02_94862_Android_htc
# num_file: 422, file_name: M0007_02_25783_Android_nexus
# num_file: 423, file_name: F0119_02_35782_Android_SM_Gal_J3
# num_file: 424, file_name: F0175_03_8105932674_Android_SM
# num_file: 425, file_name: F0119_02_69140_Android_SM_Gal_J3
# num_file: 426, file_name: M0057_03_2594680137_iPhone_6s
# num_file: 427, file_name: M0070_03_6382074195_iPhone_iphone6
# num_file: 428, file_name: M0058_02_5064821793_Android_htc
# num_file: 429, file_name: M0012_03_1832965470_Android_SM_Gal_J3
# num_file: 430, file_name: F0005_03_6879204135_Android_nexus
# num_file: 431, file_name: M0037_03_06931_Android_nexus
# num_file: 432, file_name: F0052_01_23679_iPhone_6s
# num_file: 433, file_name: M0041_02_42163_Android_SM
# num_file: 434, file_name: M0057_02_3175684920_Android_nexus
# num_file: 435, file_name: M0046_01_5031862974_iPhone_Iphone5
# num_file: 436, file_name: F0010_02_42365_iPhone_iphone6
# num_file: 437, file_name: F0152_03_95102_iPhone_6s
# num_file: 438, file_name: M0012_01_70216_iPhone_6s
# num_file: 439, file_name: M0055_02_17538_Android_htc
# num_file: 440, file_name: M0013_03_45921_Android_SM_Gal_J3
# num_file: 441, file_name: F0191_02_20759_Android_nexus
# num_file: 442, file_name: M0076_02_49586_Android_nexus
# num_file: 443, file_name: F0119_03_31248_iPhone_6s
# num_file: 444, file_name: M0078_02_4850126937_Android_SM_Gal_J3
# num_file: 445, file_name: F0010_03_30245_iPhone_6s
# num_file: 446, file_name: M0006_01_54398_iPhone_6s
# num_file: 447, file_name: F0010_02_1894372056_iPhone_iphone6
# num_file: 448, file_name: M0077_02_2760493815_Android_SM_Gal_J3
# num_file: 449, file_name: M0089_01_97842_Android_SM
# num_file: 450, file_name: F0029_02_4029763518_iPhone_iphone6
# num_file: 451, file_name: F0061_03_41693_Android_htc
# num_file: 452, file_name: M0067_02_74096_Android_SM_Gal_J3
# num_file: 453, file_name: M0056_02_1392408567_iPhone_iphone6
# num_file: 454, file_name: F0069_03_97642_Android_htc
# num_file: 455, file_name: M0039_03_7259843016_Android_nexus
# num_file: 456, file_name: F0050_01_3710859426_Android_SM
# num_file: 457, file_name: M0083_01_01294_iPhone_6s
# num_file: 458, file_name: M0046_01_9108765423_iPhone_Iphone5
# num_file: 459, file_name: M0002_01_9761823504_iPhone_6s
# num_file: 460, file_name: M0070_02_4602935718_Android_nexus
# num_file: 461, file_name: M0002_02_0578342619_Android_htc
# num_file: 462, file_name: M0006_03_8795106423_Android_nexus
# num_file: 463, file_name: F0152_03_8107293465_iPhone_6s
# num_file: 464, file_name: F0051_02_17538_Android_htc
# num_file: 465, file_name: M0036_01_70296_iPhone_Iphone5
# num_file: 466, file_name: M0046_03_46972_Android_SM
# num_file: 467, file_name: M0070_03_9156438702_Android_htc
# num_file: 468, file_name: F0009_02_89254_Android_htc
# num_file: 469, file_name: M0047_03_45921_Android_SM_Gal_J3
# num_file: 470, file_name: M0065_03_83971_iPhone_iphone6
# num_file: 471, file_name: M0067_02_2104796583_Android_SM_Gal_J3
# num_file: 472, file_name: F0035_03_18572_Android_nexus
# num_file: 473, file_name: M0039_03_2938750416_Android_SM_Gal_J3
# num_file: 474, file_name: M0043_01_04859_iPhone_Iphone5
# num_file: 475, file_name: F0175_03_31759_iPhone_6s
# num_file: 476, file_name: M0058_02_4029763518_iPhone_iphone6
# num_file: 477, file_name: F0020_03_73890_Android_SM
# num_file: 478, file_name: F0073_03_16235_Android_htc
# num_file: 479, file_name: M0016_03_85310_Android_SM
# num_file: 480, file_name: F0169_02_51386_iPhone_iphone6
# num_file: 481, file_name: F0199_02_4029763518_iPhone_iphone6
# num_file: 482, file_name: F0010_02_51386_iPhone_iphone6
# num_file: 483, file_name: F0015_03_1532879406_Android_SM_Gal_J3
# num_file: 484, file_name: M0083_01_2360481975_iPhone_6s
# num_file: 485, file_name: M0048_02_1392408567_iPhone_iphone6
# num_file: 486, file_name: M0075_03_47908_Android_SM
# num_file: 487, file_name: F0051_03_54329_Android_nexus
# num_file: 488, file_name: M0067_03_6382975401_Android_htc
# num_file: 489, file_name: F0200_02_91605_iPhone_6s
# num_file: 490, file_name: M0047_03_73068_Android_SM_Gal_J3
# num_file: 491, file_name: M0038_01_9064728153_iPhone_Iphone5
# num_file: 492, file_name: M0028_03_71638_Android_nexus
# num_file: 493, file_name: F0068_02_83172_Android_nexus
# num_file: 494, file_name: F0169_02_1392408567_iPhone_iphone6
# num_file: 495, file_name: F0051_01_2637015489_iPhone_6s
# num_file: 496, file_name: M0041_01_9375620841_iPhone_Iphone5
# num_file: 497, file_name: F0172_02_89071_iPhone_iphone6
# num_file: 498, file_name: F0117_01_15698_Android_SM
# num_file: 499, file_name: M0001_02_1306459728_Android_SM
# num_file: 500, file_name: F0175_03_47908_Android_SM
# num_file: 501, file_name: F0020_03_91605_iPhone_6s
# num_file: 502, file_name: M0067_01_41853_iPhone_6s
# num_file: 503, file_name: F0073_01_61579_iPhone_6s
# num_file: 504, file_name: M0081_01_03716_iPhone_6s
# num_file: 505, file_name: M0046_01_82310_iPhone_Iphone5
# num_file: 506, file_name: F0095_01_65718_iPhone_6s
# num_file: 507, file_name: M0039_02_6780524931_Android_htc
# num_file: 508, file_name: M0039_02_1392408567_iPhone_iphone6
# num_file: 509, file_name: M0038_02_5213840967_Android_htc
# num_file: 510, file_name: F0021_03_85310_Android_SM
# num_file: 511, file_name: M0002_02_04279_iPhone_iphone6
# num_file: 512, file_name: M0013_02_23157_Android_htc
# num_file: 513, file_name: M0081_02_03271_Android_nexus
# num_file: 514, file_name: M0026_02_80316_Android_SM
# num_file: 515, file_name: F0090_01_5137206894_Android_SM
# num_file: 516, file_name: M0058_03_18970_Android_SM_Gal_J3
# num_file: 517, file_name: F0117_02_0582397146_Android_htc
# num_file: 518, file_name: F0009_03_3621857409_iPhone_6s
# num_file: 519, file_name: M0067_03_08153_Android_htc
# num_file: 520, file_name: F0022_02_8175960234_iPhone_Iphone5
# num_file: 521, file_name: F0015_03_04238_Android_SM_Gal_J3
# num_file: 522, file_name: M0002_01_54398_iPhone_6s
# num_file: 523, file_name: M0078_02_67324_Android_SM_Gal_J3
# num_file: 524, file_name: F0015_03_71638_Android_nexus
# num_file: 525, file_name: F0022_01_43652_iPhone_6s
# num_file: 526, file_name: M0044_02_1392408567_iPhone_iphone6
# num_file: 527, file_name: M0058_03_23654_Android_SM_Gal_J3
# num_file: 528, file_name: M0082_01_1427859063_iPhone_6s
# num_file: 529, file_name: F0034_03_42950_Android_nexus
# num_file: 530, file_name: M0079_02_0571928643_Android_nexus
# num_file: 531, file_name: F0130_01_8521607493_Android_SM
# num_file: 532, file_name: F0011_03_70315_Android_nexus
# num_file: 533, file_name: F0090_01_34789_iPhone_6s
# num_file: 534, file_name: F0172_03_23654_Android_SM_Gal_J3
# num_file: 535, file_name: F0034_03_71638_Android_nexus
# num_file: 536, file_name: M0041_01_39605_Android_htc
# num_file: 537, file_name: F0191_02_3510748629_Android_nexus
# num_file: 538, file_name: F0027_02_17053_Android_htc
# num_file: 539, file_name: F0200_03_6382074195_iPhone_iphone6
# num_file: 540, file_name: F0173_01_0768123549_iPhone_6s
# num_file: 541, file_name: F0201_03_98320_Android_SM_Gal_J3
# num_file: 542, file_name: F0200_01_2837051964_Android_SM_Gal_J3
# num_file: 543, file_name: F0173_03_53067_Android_SM
# num_file: 544, file_name: M0016_02_29507_iPhone_Iphone5
# num_file: 545, file_name: M0071_03_39752_Android_htc
# num_file: 546, file_name: M0077_02_05314_Android_SM_Gal_J3
# num_file: 547, file_name: F0009_01_4351796082_iPhone_6s
# num_file: 548, file_name: M0070_02_37528_Android_SM_Gal_J3
# num_file: 549, file_name: M0056_02_04279_iPhone_iphone6
# num_file: 550, file_name: F0020_02_46783_Android_htc
# num_file: 551, file_name: F0095_03_83971_iPhone_iphone6
# num_file: 552, file_name: F0119_01_62184_iPhone_6s
# num_file: 553, file_name: F0191_01_5023164879_iPhone_6s
# num_file: 554, file_name: F0169_01_02675_Android_SM
# num_file: 555, file_name: M0076_03_13740_Android_htc
# num_file: 556, file_name: F0052_02_05269_Android_htc
# num_file: 557, file_name: M0060_03_6382975401_Android_htc
# num_file: 558, file_name: M0089_02_3186450927_Android_SM_Gal_J3
# num_file: 559, file_name: M0016_03_5267981034_iPhone_6s
# num_file: 560, file_name: M0016_03_6574019823_Android_SM
# num_file: 561, file_name: M0004_01_1324670895_iPhone_6s
# num_file: 562, file_name: F0199_03_49108_Android_nexus
# num_file: 563, file_name: M0072_02_8643201957_Android_nexus
# num_file: 564, file_name: M0056_01_2637015489_iPhone_6s
# num_file: 565, file_name: F0073_02_53417_Android_SM_Gal_J3
# num_file: 566, file_name: M0045_01_35812_iPhone_Iphone5
# num_file: 567, file_name: M0088_02_5271480936_Android_nexus
# num_file: 568, file_name: M0039_01_62795_iPhone_Iphone5
# num_file: 569, file_name: F0169_02_26839_Android_htc
# num_file: 570, file_name: F0027_02_29507_iPhone_Iphone5
# num_file: 571, file_name: F0201_02_9416235780_Android_htc
# num_file: 572, file_name: M0059_03_18572_Android_nexus
# num_file: 573, file_name: F0027_01_48150_iPhone_6s
# num_file: 574, file_name: F0173_01_4895126037_iPhone_6s
# num_file: 575, file_name: F0052_03_5823604197_iPhone_6s
# num_file: 576, file_name: F0199_02_42365_iPhone_iphone6
# num_file: 577, file_name: M0070_02_05469_Android_nexus
# num_file: 578, file_name: M0058_02_04279_iPhone_iphone6
# num_file: 579, file_name: M0072_03_9745031826_Android_htc
# num_file: 580, file_name: F0152_01_90513_iPhone_6s
# num_file: 581, file_name: M0049_02_1392408567_iPhone_iphone6
# num_file: 582, file_name: F0015_02_94862_Android_htc
# num_file: 583, file_name: M0062_03_83971_iPhone_iphone6
# num_file: 584, file_name: M0064_01_9872615403_iPhone_6s
# num_file: 585, file_name: M0047_01_69175_Android_htc
# num_file: 586, file_name: F0182_03_5379128046_Android_htc
# num_file: 587, file_name: M0062_03_08153_Android_htc
# num_file: 588, file_name: F0197_03_4563207981_Android_htc
# num_file: 589, file_name: M0081_03_75423_Android_htc
# num_file: 590, file_name: F0068_03_9745031826_Android_htc
# num_file: 591, file_name: M0078_02_4057961832_Android_nexus
# num_file: 592, file_name: M0041_03_2463591087_iPhone_6s
# num_file: 593, file_name: M0082_03_6382074195_iPhone_iphone6
# num_file: 594, file_name: F0181_01_6187249305_Android_SM
# num_file: 595, file_name: M0033_02_1894372056_iPhone_iphone6
# num_file: 596, file_name: M0079_01_4789306251_iPhone_6s
# num_file: 597, file_name: F0052_02_40689_Android_htc
# num_file: 598, file_name: F0035_03_53970_Android_SM_Gal_J3
# num_file: 599, file_name: F0182_02_5926870431_Android_nexus
# num_file: 600, file_name: M0089_03_9745031826_Android_htc
# num_file: 601, file_name: F0050_02_0582397146_Android_htc
# num_file: 602, file_name: F0201_01_7096245183_iPhone_6s
# num_file: 603, file_name: M0055_02_4910725836_Android_htc
# num_file: 604, file_name: F0011_02_4029763518_iPhone_iphone6
# num_file: 605, file_name: M0058_01_87901_iPhone_6s
# num_file: 606, file_name: M0088_01_45213_Android_SM
# num_file: 607, file_name: F0117_03_42051_Android_nexus
# num_file: 608, file_name: F0052_02_4952670138_Android_htc
# num_file: 609, file_name: M0004_02_0578342619_Android_htc
# num_file: 610, file_name: F0201_02_41302_Android_htc
# num_file: 611, file_name: F0130_01_79284_Android_SM
# num_file: 612, file_name: M0067_03_79428_iPhone_iphone6
# num_file: 613, file_name: F0181_01_8167295430_iPhone_6s
# num_file: 614, file_name: F0201_02_04279_iPhone_iphone6
# num_file: 615, file_name: F0175_01_4895126037_iPhone_6s
# num_file: 616, file_name: M0053_03_5728694013_Android_SM
# num_file: 617, file_name: F0119_03_64819_Android_SM
# num_file: 618, file_name: F0011_03_39685_Android_nexus
# num_file: 619, file_name: M0059_02_51386_iPhone_iphone6
# num_file: 620, file_name: F0090_02_40179_Android_nexus
# num_file: 621, file_name: F0173_02_08931_Android_htc
# num_file: 622, file_name: M0083_03_59708_Android_htc
# num_file: 623, file_name: F0197_02_4736850219_iPhone_6s
# num_file: 624, file_name: M0037_01_48217_Android_htc
# num_file: 625, file_name: F0051_03_69570_Android_SM_Gal_J3
# num_file: 626, file_name: F0152_01_28376_iPhone_6s
# num_file: 627, file_name: M0016_01_23679_iPhone_6s
# num_file: 628, file_name: F0181_02_8923061574_Android_SM_Gal_J3
# num_file: 629, file_name: F0052_02_42365_iPhone_iphone6
# num_file: 630, file_name: M0046_02_90864_Android_htc
# num_file: 631, file_name: M0057_03_1025739486_Android_SM
# num_file: 632, file_name: F0022_03_73284_iPhone_6s
# num_file: 633, file_name: F0035_03_9263507184_Android_nexus
# num_file: 634, file_name: F0042_02_4067593812_Android_htc
# num_file: 635, file_name: F0200_02_81254_Android_SM
# num_file: 636, file_name: F0117_02_1894372056_iPhone_iphone6
# num_file: 637, file_name: F0022_01_48150_iPhone_6s
# num_file: 638, file_name: M0043_02_5037649281_Android_htc
# num_file: 639, file_name: M0053_02_79506_Android_SM
# num_file: 640, file_name: M0078_02_1906745283_Android_nexus
# num_file: 641, file_name: M0065_02_21845_Android_nexus
# num_file: 642, file_name: M0002_03_9263475180_Android_nexus
# num_file: 643, file_name: F0011_02_57049_Android_htc
# num_file: 644, file_name: F0172_02_27348_Android_htc
# num_file: 645, file_name: M0060_03_9308247615_Android_htc
# num_file: 646, file_name: M0006_03_8415260937_Android_SM_Gal_J3
# num_file: 647, file_name: M0012_01_25981_iPhone_6s
# num_file: 648, file_name: F0005_02_9730581624_Android_htc
# num_file: 649, file_name: M0062_02_97063_Android_nexus
# num_file: 650, file_name: F0157_03_4532091867_iPhone_iphone6
# num_file: 651, file_name: F0191_03_4532091867_iPhone_iphone6
# num_file: 652, file_name: F0021_03_42561_Android_SM
# num_file: 653, file_name: M0046_01_69175_Android_htc
# num_file: 654, file_name: M0002_01_70216_iPhone_6s
# num_file: 655, file_name: M0072_01_28304_iPhone_6s
# num_file: 656, file_name: F0069_03_02764_Android_htc
# num_file: 657, file_name: M0036_02_16073_Android_htc
# num_file: 658, file_name: M0016_02_1763092458_iPhone_Iphone5
# num_file: 659, file_name: M0089_02_2760493815_Android_SM_Gal_J3
# num_file: 660, file_name: M0062_02_7804526931_Android_nexus
# num_file: 661, file_name: M0028_02_5213840967_Android_htc
# num_file: 662, file_name: M0004_01_63470_iPhone_6s
# num_file: 663, file_name: M0001_02_0591634827_iPhone_6s
# num_file: 664, file_name: F0182_02_3476059812_Android_SM_Gal_J3
# num_file: 665, file_name: M0072_03_8726039514_Android_htc
# num_file: 666, file_name: F0061_03_53061_iPhone_iphone6
# num_file: 667, file_name: F0027_03_5267981034_iPhone_6s
# num_file: 668, file_name: F0015_01_87901_iPhone_6s
# num_file: 669, file_name: F0154_01_90513_iPhone_6s
# num_file: 670, file_name: M0071_02_05469_Android_nexus
# num_file: 671, file_name: M0057_03_9801763425_iPhone_6s
# num_file: 672, file_name: M0047_03_1832965470_Android_SM_Gal_J3
# num_file: 673, file_name: M0062_03_6382074195_iPhone_iphone6
# num_file: 674, file_name: M0075_02_19058_Android_SM_Gal_J3
# num_file: 675, file_name: F0050_01_2964851730_Android_SM
# num_file: 676, file_name: M0079_03_67059_iPhone_6s
# num_file: 677, file_name: M0062_02_41693_Android_nexus
# num_file: 678, file_name: F0051_02_1392408567_iPhone_iphone6
# num_file: 679, file_name: M0075_01_28304_iPhone_6s
# num_file: 680, file_name: F0175_01_7419068325_iPhone_6s
# num_file: 681, file_name: M0062_02_21845_Android_nexus
# num_file: 682, file_name: M0006_02_17538_Android_htc
# num_file: 683, file_name: F0027_02_6714258309_Android_htc
# num_file: 684, file_name: F0015_02_6714258309_Android_htc
# num_file: 685, file_name: M0039_01_48217_Android_htc
# num_file: 686, file_name: M0074_02_98542_iPhone_6s
# num_file: 687, file_name: M0055_01_5326071948_iPhone_6s
# num_file: 688, file_name: F0027_02_8175960234_iPhone_Iphone5
# num_file: 689, file_name: F0172_03_3142985706_Android_nexus
# num_file: 690, file_name: F0031_02_5213840967_Android_htc
# num_file: 691, file_name: F0172_03_17983_Android_nexus
# num_file: 692, file_name: M0013_02_04279_iPhone_iphone6
# num_file: 693, file_name: F0010_03_27351_iPhone_6s
# num_file: 694, file_name: F0022_02_17053_Android_htc
# num_file: 695, file_name: M0038_01_38041_iPhone_Iphone5
# num_file: 696, file_name: F0061_02_10694_Android_SM_Gal_J3
# num_file: 697, file_name: M0077_01_47016_iPhone_6s
# num_file: 698, file_name: F0090_03_42739_Android_SM
# num_file: 699, file_name: M0053_03_59247_iPhone_6s
# num_file: 700, file_name: F0027_01_5326071948_iPhone_6s
# num_file: 701, file_name: M0012_03_84312_Android_SM_Gal_J3
# num_file: 702, file_name: M0070_02_7963108245_Android_nexus
# num_file: 703, file_name: M0036_03_92706_Android_SM
# num_file: 704, file_name: M0064_02_97063_Android_nexus
# num_file: 705, file_name: M0077_02_49826_Android_nexus
# num_file: 706, file_name: M0045_03_09687_Android_SM
# num_file: 707, file_name: M0082_01_03716_iPhone_6s
# num_file: 708, file_name: M0062_01_2593068741_iPhone_6s
# num_file: 709, file_name: M0060_03_97642_Android_htc
# num_file: 710, file_name: M0045_03_1854329706_iPhone_6s
# num_file: 711, file_name: M0070_02_15238_Android_SM_Gal_J3
# num_file: 712, file_name: M0016_01_2637015489_iPhone_6s
# num_file: 713, file_name: F0199_02_41302_Android_htc
# num_file: 714, file_name: M0044_01_50734_Android_htc
# num_file: 715, file_name: F0034_01_2593068741_iPhone_Iphone5
# num_file: 716, file_name: F0197_03_6382074195_iPhone_iphone6
# num_file: 717, file_name: M0053_02_21094_iPhone_6s
# num_file: 718, file_name: F0050_02_04279_iPhone_iphone6
# num_file: 719, file_name: M0047_02_72593_iPhone_6s
# num_file: 720, file_name: M0062_01_4523869701_iPhone_6s
# num_file: 721, file_name: M0072_03_2738015469_iPhone_iphone6
# num_file: 722, file_name: M0004_02_42365_iPhone_iphone6
# num_file: 723, file_name: F0032_03_1230694587_Android_SM
# num_file: 724, file_name: F0029_02_42365_iPhone_iphone6
# num_file: 725, file_name: F0157_03_53061_iPhone_iphone6
# num_file: 726, file_name: M0036_03_14358_Android_SM
# num_file: 727, file_name: M0078_01_28304_iPhone_6s
# num_file: 728, file_name: F0031_02_5037649281_Android_htc
# num_file: 729, file_name: F0051_03_9203745681_Android_nexus
# num_file: 730, file_name: M0083_03_48790_Android_htc
# num_file: 731, file_name: F0090_02_6819427305_Android_SM_Gal_J3
# num_file: 732, file_name: M0038_02_74681_Android_htc
# num_file: 733, file_name: M0089_01_70968_Android_SM
# num_file: 734, file_name: F0035_02_4029763518_iPhone_iphone6
# num_file: 735, file_name: F0034_02_1253068479_Android_htc
# num_file: 736, file_name: F0117_03_5498702613_Android_nexus
# num_file: 737, file_name: M0088_01_50216_iPhone_6s
# num_file: 738, file_name: F0027_03_0931472685_Android_SM
# num_file: 739, file_name: M0053_01_2637015489_iPhone_6s
# num_file: 740, file_name: F0197_01_7546301298_Android_nexus
# num_file: 741, file_name: M0037_01_75963_Android_htc
# num_file: 742, file_name: M0038_01_08142_Android_htc
# num_file: 743, file_name: F0073_02_24801_Android_nexus
# num_file: 744, file_name: M0055_03_59012_Android_SM_Gal_J3
# num_file: 745, file_name: F0061_02_15238_Android_SM_Gal_J3
# num_file: 746, file_name: M0081_01_65387_iPhone_6s
# num_file: 747, file_name: F0022_03_6574019823_Android_SM
# num_file: 748, file_name: F0068_03_9156438702_Android_htc
# num_file: 749, file_name: M0016_03_12948_iPhone_6s
# num_file: 750, file_name: M0075_01_2765304981_iPhone_6s
# num_file: 751, file_name: M0044_01_4682107593_iPhone_Iphone5
# num_file: 752, file_name: M0041_02_01748_iPhone_6s
# num_file: 753, file_name: M0013_01_1324670895_iPhone_6s
# num_file: 754, file_name: F0173_01_87046_iPhone_6s
# num_file: 755, file_name: M0060_01_43652_iPhone_6s
# num_file: 756, file_name: F0042_01_4762598103_Android_htc
# num_file: 757, file_name: F0119_02_5462170398_Android_SM_Gal_J3
# num_file: 758, file_name: M0076_03_9156438702_Android_htc
# num_file: 759, file_name: F0199_03_73652_Android_nexus
# num_file: 760, file_name: F0119_02_9716524380_Android_nexus
# num_file: 761, file_name: M0026_02_65978_iPhone_6s
# num_file: 762, file_name: F0032_02_51386_iPhone_iphone6
# num_file: 763, file_name: F0119_03_2341895760_Android_SM
# num_file: 764, file_name: F0200_03_90741_Android_htc
# num_file: 765, file_name: M0026_03_0793286541_Android_SM
# num_file: 766, file_name: M0053_03_32054_iPhone_6s
# num_file: 767, file_name: M0082_03_53061_iPhone_iphone6
# num_file: 768, file_name: F0117_02_51386_iPhone_iphone6
# num_file: 769, file_name: F0197_01_2837051964_Android_SM_Gal_J3
# num_file: 770, file_name: M0047_02_2416893507_iPhone_6s
# num_file: 771, file_name: F0061_03_7658043921_Android_htc
# num_file: 772, file_name: F0199_01_7239856140_Android_SM_Gal_J3
# num_file: 773, file_name: F0042_02_51386_iPhone_iphone6
# num_file: 774, file_name: F0021_02_1894372056_iPhone_iphone6
# num_file: 775, file_name: M0044_01_10854_Android_htc
# num_file: 776, file_name: F0157_03_07516_Android_htc
# num_file: 777, file_name: F0015_02_21706_iPhone_Iphone5
# num_file: 778, file_name: M0036_01_41853_iPhone_Iphone5
# num_file: 779, file_name: F0191_01_86794_Android_SM
# num_file: 780, file_name: M0074_02_5041896723_Android_SM
# num_file: 781, file_name: F0022_02_63148_iPhone_Iphone5
# num_file: 782, file_name: M0089_01_50216_iPhone_6s
# num_file: 783, file_name: M0059_02_29640_Android_htc
# num_file: 784, file_name: F0042_01_51902_iPhone_Iphone5
# num_file: 785, file_name: F0095_03_2931068574_Android_htc
# num_file: 786, file_name: M0028_02_21706_iPhone_Iphone5
# num_file: 787, file_name: M0081_01_89524_iPhone_6s
# num_file: 788, file_name: F0034_03_14769_Android_SM_Gal_J3
# num_file: 789, file_name: M0028_03_74126_Android_nexus
# num_file: 790, file_name: F0095_03_48790_Android_htc
# num_file: 791, file_name: M0060_03_62045_iPhone_iphone6
# num_file: 792, file_name: F0175_02_50217_Android_nexus
# num_file: 793, file_name: M0079_02_7804526931_Android_nexus
# num_file: 794, file_name: M0043_01_0762453891_Android_htc
# num_file: 795, file_name: F0197_03_39752_Android_htc
# num_file: 796, file_name: F0042_01_75963_Android_htc
# num_file: 797, file_name: M0036_03_1854329706_iPhone_6s
# num_file: 798, file_name: F0157_01_27864_iPhone_6s
# num_file: 799, file_name: F0095_03_62045_iPhone_iphone6
# num_file: 800, file_name: M0047_02_1723496085_iPhone_6s
# num_file: 801, file_name: M0030_03_2107835946_iPhone_6s
# num_file: 802, file_name: M0067_03_4532091867_iPhone_iphone6
# num_file: 803, file_name: F0173_03_4263107589_iPhone_6s
# num_file: 804, file_name: F0009_03_4762093185_iPhone_6s
# num_file: 805, file_name: F0035_02_89071_iPhone_iphone6
# num_file: 806, file_name: F0061_02_8719463205_Android_SM_Gal_J3
# num_file: 807, file_name: F0020_02_1392408567_iPhone_iphone6
# num_file: 808, file_name: M0038_02_59021_Android_htc
# num_file: 809, file_name: F0068_03_26738_Android_htc
# num_file: 810, file_name: M0082_03_9308247615_Android_htc
# num_file: 811, file_name: F0181_02_82673_Android_SM_Gal_J3
# num_file: 812, file_name: M0072_02_37528_Android_SM_Gal_J3
# num_file: 813, file_name: M0089_02_89276_Android_SM_Gal_J3
# num_file: 814, file_name: M0013_02_90864_Android_htc
# num_file: 815, file_name: M0072_02_2104796583_Android_SM_Gal_J3
# num_file: 816, file_name: F0051_01_23679_iPhone_6s
# num_file: 817, file_name: F0021_02_4029763518_iPhone_iphone6
# num_file: 818, file_name: F0119_02_91082_Android_nexus
# num_file: 819, file_name: M0059_02_4067593812_Android_htc
# num_file: 820, file_name: M0045_01_0762453891_Android_htc
# num_file: 821, file_name: F0191_02_3476059812_Android_SM_Gal_J3
# num_file: 822, file_name: M0076_01_47016_iPhone_6s
# num_file: 823, file_name: M0026_03_42739_Android_SM
# num_file: 824, file_name: F0010_03_6431972580_iPhone_6s
# num_file: 825, file_name: M0036_01_9872615403_iPhone_Iphone5
# num_file: 826, file_name: M0036_03_1230694587_Android_SM
# num_file: 827, file_name: F0200_03_26538_Android_htc
# num_file: 828, file_name: M0058_03_53970_Android_SM_Gal_J3
# num_file: 829, file_name: F0119_03_5179083462_iPhone_6s
# num_file: 830, file_name: F0061_01_41853_iPhone_6s
# num_file: 831, file_name: M0076_01_61579_iPhone_6s
# num_file: 832, file_name: F0051_03_3792846105_Android_nexus
# num_file: 833, file_name: M0088_02_85109_Android_nexus
# num_file: 834, file_name: M0055_03_8415260937_Android_SM_Gal_J3
# num_file: 835, file_name: M0072_03_9156438702_Android_htc
# num_file: 836, file_name: M0081_02_2104796583_Android_SM_Gal_J3
# num_file: 837, file_name: F0095_03_79428_iPhone_iphone6
# num_file: 838, file_name: M0033_03_53980_Android_nexus
# num_file: 839, file_name: M0055_01_23679_iPhone_6s
# num_file: 840, file_name: F0130_01_1935482760_Android_SM
# num_file: 841, file_name: M0089_01_34789_iPhone_6s
# num_file: 842, file_name: F0168_03_82493_Android_htc
# num_file: 843, file_name: M0044_01_6918207345_iPhone_Iphone5
# num_file: 844, file_name: F0052_02_51386_iPhone_iphone6
# num_file: 845, file_name: F0173_02_6374801259_Android_htc
# num_file: 846, file_name: M0055_03_34786_Android_SM_Gal_J3
# num_file: 847, file_name: F0117_01_9726431850_Android_SM
# num_file: 848, file_name: F0191_03_79428_iPhone_iphone6
# num_file: 849, file_name: F0042_03_69570_Android_SM_Gal_J3
# num_file: 850, file_name: F0051_02_51386_iPhone_iphone6
# num_file: 851, file_name: F0035_01_98264_iPhone_Iphone5
# num_file: 852, file_name: M0079_03_5179083462_iPhone_6s
# num_file: 853, file_name: M0002_03_1532879406_Android_SM_Gal_J3
# num_file: 854, file_name: M0059_01_43652_iPhone_6s
# num_file: 855, file_name: M0058_03_18572_Android_nexus
# num_file: 856, file_name: F0119_01_75362_Android_SM
# num_file: 857, file_name: F0197_01_26094_Android_nexus
# num_file: 858, file_name: F0172_01_29351_iPhone_6s
# num_file: 859, file_name: M0044_02_4029763518_iPhone_iphone6
# num_file: 860, file_name: F0032_02_1392408567_iPhone_iphone6
# num_file: 861, file_name: M0037_03_7259843016_Android_nexus
# num_file: 862, file_name: M0030_01_2593068741_iPhone_Iphone5
# num_file: 863, file_name: F0010_02_29845_Android_htc
# num_file: 864, file_name: F0031_01_9872615403_iPhone_Iphone5
# num_file: 865, file_name: F0015_01_23679_iPhone_6s
# num_file: 866, file_name: M0016_01_8102574936_iPhone_6s
# num_file: 867, file_name: M0033_03_5873419602_Android_nexus
# num_file: 868, file_name: F0010_03_86197_iPhone_6s
# num_file: 869, file_name: F0061_02_4602935718_Android_nexus
# num_file: 870, file_name: F0021_03_56307_iPhone_6s
# num_file: 871, file_name: M0089_03_14590_Android_htc
# num_file: 872, file_name: M0071_03_21057_Android_htc
# num_file: 873, file_name: F0191_03_53061_iPhone_iphone6
# num_file: 874, file_name: F0154_01_15847_Android_SM
# num_file: 875, file_name: F0173_02_89071_iPhone_iphone6
# num_file: 876, file_name: M0070_02_2104796583_Android_SM_Gal_J3
# num_file: 877, file_name: F0182_03_4532091867_iPhone_iphone6
# num_file: 878, file_name: M0047_01_4027851963_Android_htc
# num_file: 879, file_name: M0075_02_13856_Android_nexus
# num_file: 880, file_name: F0095_03_3098451762_Android_htc
# num_file: 881, file_name: F0191_03_39752_Android_htc
# num_file: 882, file_name: M0002_02_17360_Android_htc
# num_file: 883, file_name: M0067_02_15238_Android_SM_Gal_J3
# num_file: 884, file_name: F0090_01_03156_Android_SM
# num_file: 885, file_name: F0010_02_90864_Android_htc
# num_file: 886, file_name: F0051_03_73068_Android_SM_Gal_J3
# num_file: 887, file_name: F0061_03_2738015469_iPhone_iphone6
# num_file: 888, file_name: M0056_02_42365_iPhone_iphone6
# num_file: 889, file_name: M0071_01_7108563429_iPhone_6s
# num_file: 890, file_name: M0067_03_02764_Android_htc
# num_file: 891, file_name: F0172_02_4263908751_Android_htc
# num_file: 892, file_name: M0088_01_65718_iPhone_6s
# num_file: 893, file_name: M0030_02_46783_Android_htc
# num_file: 894, file_name: F0021_03_73284_iPhone_6s
# num_file: 895, file_name: F0090_03_3978520416_iPhone_6s
# num_file: 896, file_name: F0173_02_51386_iPhone_iphone6
# num_file: 897, file_name: F0051_02_4029763518_iPhone_iphone6
# num_file: 898, file_name: M0083_01_03716_iPhone_6s
# num_file: 899, file_name: M0079_01_1427859063_iPhone_6s
# num_file: 900, file_name: M0047_03_3729158604_Android_SM_Gal_J3
# num_file: 901, file_name: F0090_02_62831_Android_SM_Gal_J3
# num_file: 902, file_name: M0067_02_8719463205_Android_SM_Gal_J3
# num_file: 903, file_name: M0026_03_38467_iPhone_6s
# num_file: 904, file_name: M0001_03_8415260937_Android_SM_Gal_J3
# num_file: 905, file_name: M0071_03_83971_iPhone_iphone6
# num_file: 906, file_name: M0036_02_90864_Android_htc
# num_file: 907, file_name: M0006_01_70216_iPhone_6s
# num_file: 908, file_name: F0197_03_21057_Android_htc
# num_file: 909, file_name: F0090_02_6594720318_Android_nexus
# num_file: 910, file_name: F0021_02_6780524931_Android_htc
# num_file: 911, file_name: M0007_01_54398_iPhone_6s
# num_file: 912, file_name: F0029_02_5213840967_Android_htc
# num_file: 913, file_name: F0095_01_3917620845_iPhone_6s
# num_file: 914, file_name: M0076_02_15238_Android_SM_Gal_J3
# num_file: 915, file_name: M0033_03_1532879406_Android_SM_Gal_J3
# num_file: 916, file_name: F0061_02_74096_Android_SM_Gal_J3
# num_file: 917, file_name: F0073_02_59637_Android_nexus
# num_file: 918, file_name: M0004_03_86071_Android_nexus
# num_file: 919, file_name: M0089_03_79428_iPhone_iphone6
# num_file: 920, file_name: F0200_03_4532091867_iPhone_iphone6
# num_file: 921, file_name: F0191_01_21053_Android_SM
# num_file: 922, file_name: M0012_03_45921_Android_SM_Gal_J3
# num_file: 923, file_name: M0076_01_6527480931_iPhone_6s
# num_file: 924, file_name: M0004_02_03924_Android_htc
# num_file: 925, file_name: M0060_02_0571928643_Android_nexus
# num_file: 926, file_name: M0079_03_64819_Android_SM
# num_file: 927, file_name: F0169_01_4895126037_iPhone_6s
# num_file: 928, file_name: F0154_01_28376_iPhone_6s
# num_file: 929, file_name: M0012_01_4351796082_iPhone_6s
# num_file: 930, file_name: F0182_02_82673_Android_SM_Gal_J3
# num_file: 931, file_name: M0045_02_42365_iPhone_iphone6
# num_file: 932, file_name: M0071_02_4602935718_Android_nexus
# num_file: 933, file_name: F0032_03_14358_Android_SM
# num_file: 934, file_name: F0095_01_7458109632_Android_SM
# num_file: 935, file_name: M0075_01_7108563429_iPhone_6s
# num_file: 936, file_name: M0089_03_2738015469_iPhone_iphone6
# num_file: 937, file_name: F0172_02_25647_Android_htc
# num_file: 938, file_name: M0038_01_0594267381_Android_htc
# num_file: 939, file_name: F0005_03_20174_Android_nexus
# num_file: 940, file_name: F0157_01_15847_Android_SM
# num_file: 941, file_name: M0007_03_40826_iPhone_6s
# num_file: 942, file_name: M0082_02_03271_Android_nexus
# num_file: 943, file_name: M0056_01_87901_iPhone_6s
# num_file: 944, file_name: F0011_02_17538_Android_htc
# num_file: 945, file_name: M0074_03_29136_iPhone_6s
# num_file: 946, file_name: F0130_02_91082_Android_nexus
# num_file: 947, file_name: F0035_01_70531_iPhone_Iphone5
# num_file: 948, file_name: M0056_03_7542063198_Android_SM
# num_file: 949, file_name: M0038_01_51902_iPhone_Iphone5
# num_file: 950, file_name: M0030_03_73890_Android_SM
# num_file: 951, file_name: M0045_01_10854_Android_htc
# num_file: 952, file_name: M0071_01_6527480931_iPhone_6s
# num_file: 953, file_name: F0031_03_4039618572_iPhone_6s
# num_file: 954, file_name: M0041_01_9064728153_iPhone_Iphone5
# num_file: 955, file_name: M0007_02_62934_Android_SM_Gal_J3
# num_file: 956, file_name: F0090_01_24309_iPhone_6s
# num_file: 957, file_name: M0082_02_15238_Android_SM_Gal_J3
# num_file: 958, file_name: M0044_02_95230_Android_htc
# num_file: 959, file_name: F0199_02_9416235780_Android_htc
# num_file: 960, file_name: M0036_02_89071_iPhone_iphone6
# num_file: 961, file_name: F0032_01_98264_iPhone_Iphone5
# num_file: 962, file_name: M0030_02_74681_Android_htc
# num_file: 963, file_name: F0200_02_74832_iPhone_6s
# num_file: 964, file_name: F0027_01_8102574936_iPhone_6s
# num_file: 965, file_name: F0172_03_6987543021_Android_SM_Gal_J3
# num_file: 966, file_name: F0191_03_6382074195_iPhone_iphone6
# num_file: 967, file_name: M0016_02_94862_Android_htc
# num_file: 968, file_name: F0027_02_9367254810_Android_htc
# num_file: 969, file_name: M0041_03_12590_iPhone_6s
# num_file: 970, file_name: M0083_02_5692438017_Android_SM_Gal_J3
# num_file: 971, file_name: F0010_01_54398_iPhone_6s
# num_file: 972, file_name: M0059_02_89071_iPhone_iphone6
# num_file: 973, file_name: M0075_03_9801763425_iPhone_6s
# num_file: 974, file_name: M0055_02_89071_iPhone_iphone6
# num_file: 975, file_name: F0069_02_0571928643_Android_nexus
# num_file: 976, file_name: M0058_02_51386_iPhone_iphone6
# num_file: 977, file_name: M0038_03_41235_Android_SM
# num_file: 978, file_name: F0201_01_07589_iPhone_6s
# num_file: 979, file_name: M0055_03_5734802691_Android_nexus
# num_file: 980, file_name: M0074_02_76013_iPhone_6s
# num_file: 981, file_name: F0152_03_3978520416_iPhone_6s
# num_file: 982, file_name: M0037_02_5064821793_Android_htc
# num_file: 983, file_name: F0152_01_0435891276_iPhone_6s
# num_file: 984, file_name: F0197_03_4532091867_iPhone_iphone6
# num_file: 985, file_name: M0002_03_5873419602_Android_nexus
# num_file: 986, file_name: M0046_02_5064821793_Android_htc
# num_file: 987, file_name: M0065_02_3017568429_Android_nexus
# num_file: 988, file_name: M0047_03_3792846105_Android_nexus
# num_file: 989, file_name: M0065_03_08153_Android_htc
# num_file: 990, file_name: F0181_01_8076135429_Android_SM
# num_file: 991, file_name: M0075_03_60475_iPhone_6s
# num_file: 992, file_name: F0117_02_1392408567_iPhone_iphone6
# num_file: 993, file_name: F0201_03_1463925078_Android_SM_Gal_J3
# num_file: 994, file_name: M0077_01_61579_iPhone_6s
# num_file: 995, file_name: M0075_01_6527480931_iPhone_6s
# num_file: 996, file_name: F0154_03_2543781960_Android_nexus
# num_file: 997, file_name: F0073_02_1397860254_Android_SM_Gal_J3
# num_file: 998, file_name: F0022_02_6107523948_Android_htc
# num_file: 999, file_name: F0181_02_04837_Android_SM_Gal_J3
#
# ----------RESULT OF RECOGNITION:--------------------
#
# %WER is 14.31
#
# TOTAL TIME: 4 min 27.22 sec
# RTF: 0.058
